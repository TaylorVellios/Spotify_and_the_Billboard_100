# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import json
import matplotlib.pyplot as plt
import statistics as stats
from credentials import client_id, client_secret
import time

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
billboard = 'Clean_Billboard.csv'
billboard_df = pd.read_csv(billboard)
billboard_df
# Out:
#               date  rank               song  \
# 0       1958-08-04     1   Poor Little Fool
# 1       1958-08-04     2           Patricia
# 2       1958-08-04     3      Splish Splash
# 3       1958-08-04     4  Hard Headed Woman
# 4       1958-08-04     5               When
# ...            ...   ...                ...
# 326682  2021-03-13    96             Nobody
# 326683  2021-03-13    97        Cover Me Up
# 326684  2021-03-13    98    Like I Want You
# 326685  2021-03-13    99               Gone
# 326686  2021-03-13   100            Bichota
#
#                                     artist  last-week  peak-rank  \
# 0                             Ricky Nelson        0.0          1
# 1            Perez Prado And His Orchestra        0.0          2
# 2                              Bobby Darin        0.0          3
# 3       Elvis Presley With The Jordanaires        0.0          4
# 4                              Kalin Twins        0.0          5
# ...                                    ...        ...        ...
# 326682                         Dylan Scott        0.0         96
# 326683                       Morgan Wallen       95.0         52
# 326684                              Giveon      100.0         95
# 326685                      Dierks Bentley        0.0         99
# 326686                             Karol G        0.0         72
#
#         weeks-on-board
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 326682               1
# 326683               9
# 326684               3
# 326685               1
# 326686              13
#
# [326687 rows x 7 columns]

# %% [markdown]
# # Main Filter!
# ### This is where we filter the billboard top100 charts to search spotify with

# %%
#SET THIS VARIABLE FOR OUTPUT CSV FILE NAMES LATER ON IN THIS NOTEBOOK
filter_range = '2015-2020'

# %%
filtered_df = billboard_df[(billboard_df['date'] > '2015-01-01') &
                              (billboard_df['date'] < '2020-01-01')]

filtered_df.reset_index(drop=True)
# Out:
#              date  rank               song  \
# 0      2015-01-03     1        Blank Space
# 1      2015-01-03     2  Take Me To Church
# 2      2015-01-03     3       Uptown Funk!
# 3      2015-01-03     4  Thinking Out Loud
# 4      2015-01-03     5     Lips Are Movin
# ...           ...   ...                ...
# 26095  2019-12-28    96           Homesick
# 26096  2019-12-28    97               Easy
# 26097  2019-12-28    98            Enemies
# 26098  2019-12-28    99                She
# 26099  2019-12-28   100             6 Kiss
#
#                                               artist  last-week  peak-rank  \
# 0                                       Taylor Swift        1.0          1
# 1                                             Hozier        2.0          2
# 2                   Mark Ronson Featuring Bruno Mars        3.0          3
# 3                                         Ed Sheeran        6.0          4
# 4                                     Meghan Trainor        4.0          4
# ...                                              ...        ...        ...
# 26095                                     Kane Brown       90.0         88
# 26096                DaniLeigh Featuring Chris Brown       89.0         88
# 26097                   Post Malone Featuring DaBaby       83.0         16
# 26098                                   Harry Styles        0.0         99
# 26099  Trippie Redd Featuring Juice WRLD & YNW Melly       78.0         60
#
#        weeks-on-board
# 0                   8
# 1                  19
# 2                   6
# 3                  11
# 4                   9
# ...               ...
# 26095               5
# 26096               7
# 26097              15
# 26098               1
# 26099               4
#
# [26100 rows x 7 columns]

# %% [markdown]
# # Consolidating the Data Frame

# %%
consolidate = filtered_df[['date','song','artist','peak-rank']].copy()
consolidate['track_art'] = consolidate['song'] + ' ' + consolidate['artist']
consolidate
# Out:
#               date               song  \
# 294287  2015-01-03        Blank Space
# 294288  2015-01-03  Take Me To Church
# 294289  2015-01-03       Uptown Funk!
# 294290  2015-01-03  Thinking Out Loud
# 294291  2015-01-03     Lips Are Movin
# ...            ...                ...
# 320382  2019-12-28           Homesick
# 320383  2019-12-28               Easy
# 320384  2019-12-28            Enemies
# 320385  2019-12-28                She
# 320386  2019-12-28             6 Kiss
#
#                                                artist  peak-rank  \
# 294287                                   Taylor Swift          1
# 294288                                         Hozier          2
# 294289               Mark Ronson Featuring Bruno Mars          3
# 294290                                     Ed Sheeran          4
# 294291                                 Meghan Trainor          4
# ...                                               ...        ...
# 320382                                     Kane Brown         88
# 320383                DaniLeigh Featuring Chris Brown         88
# 320384                   Post Malone Featuring DaBaby         16
# 320385                                   Harry Styles         99
# 320386  Trippie Redd Featuring Juice WRLD & YNW Melly         60
#
#                                                 track_art
# 294287                           Blank Space Taylor Swift
# 294288                           Take Me To Church Hozier
# 294289      Uptown Funk! Mark Ronson Featuring Bruno Mars
# 294290                       Thinking Out Loud Ed Sheeran
# 294291                      Lips Are Movin Meghan Trainor
# ...                                                   ...
# 320382                                Homesick Kane Brown
# 320383               Easy DaniLeigh Featuring Chris Brown
# 320384               Enemies Post Malone Featuring DaBaby
# 320385                                   She Harry Styles
# 320386  6 Kiss Trippie Redd Featuring Juice WRLD & YNW...
#
# [26100 rows x 5 columns]

# %% [markdown]
# # Iterate Through the DF to Prepare for Searching
# Removing Duplicates, Creating a column for list of all weeks a song is present, ensuring the "peak-rank" is the highest value given to a track during any position in its chart history.

# %%
check = {}
peak_ranks = {}
for ind,row in consolidate.iterrows():
    week = row['date']
    peak_rank = max(consolidate['peak-rank'].loc[(consolidate['track_art']==row['track_art'])])
    if row['track_art'] in check.keys():
        check[row['track_art']].append(week)

    else:
        check[row['track_art']] = []
        check[row['track_art']].append(week)
        
        peak_ranks[row['track_art']] = peak_rank

# %% [markdown]
# ## Create New Columns, Drop Duplicate Rows, Update 'weeks_on_board'

# %%
consolidate['all_weeks'] = consolidate['track_art'].map(check)
consolidate['peak-rank'] = consolidate['track_art'].map(peak_ranks)

consolidated_tosearch = consolidate.drop(columns=['date','track_art']).reset_index(drop=True)

consolidated_tosearch = consolidated_tosearch.drop_duplicates(subset=['song','artist']).reset_index(drop=True)
consolidated_tosearch['weeks_on_board'] = [len(i) for i in consolidated_tosearch['all_weeks']]
consolidated_tosearch
# Out:
#                    song                                artist  peak-rank  \
# 0           Blank Space                          Taylor Swift          1
# 1     Take Me To Church                                Hozier          2
# 2          Uptown Funk!      Mark Ronson Featuring Bruno Mars          3
# 3     Thinking Out Loud                            Ed Sheeran          4
# 4        Lips Are Movin                        Meghan Trainor          4
# ...                 ...                                   ...        ...
# 2495     Nobody But You  Blake Shelton Duet With Gwen Stefani         79
# 2496        Famous Hoes                            NLE Choppa         83
# 2497             Cherry                          Harry Styles         84
# 2498             Golden                          Harry Styles         86
# 2499                She                          Harry Styles         99
#
#                                               all_weeks  weeks_on_board
# 0     [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...              29
# 1     [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...              23
# 2     [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...              51
# 3     [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...              48
# 4     [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...              21
# ...                                                 ...             ...
# 2495                                       [2019-12-28]               1
# 2496                                       [2019-12-28]               1
# 2497                                       [2019-12-28]               1
# 2498                                       [2019-12-28]               1
# 2499                                       [2019-12-28]               1
#
# [2500 rows x 5 columns]

# %% [markdown]
# # Checking Artist Names for any Strange symbols that might hurt the search process.
# ### Things like ['featuring','&','x','with','+',',']
# Every decade introduces new roadblocks with trying to automatically search spotify. Every failed search will be manually searched in the next step, non-alphanumeric characters do not fly with spotify searching

# %%
[i.split() for i in consolidated_tosearch['artist'] if len(i.split()) > 2]
# Out:
# [['Mark', 'Ronson', 'Featuring', 'Bruno', 'Mars'],
#  ['Ariana', 'Grande', '&', 'The', 'Weeknd'],
#  ['Big', 'Sean', 'Featuring', 'E-40'],
#  ['Nicki',
#   'Minaj',
#   'Featuring',
#   'Drake,',
#   'Lil',
#   'Wayne',
#   '&',
#   'Chris',
#   'Brown'],
#  ['I', 'LOVE', 'MAKONNEN', 'Featuring', 'Drake'],
#  ['Fall', 'Out', 'Boy'],
#  ['James', 'Newton', 'Howard', 'Featuring', 'Jennifer', 'Lawrence'],
#  ['Jessie', 'J,', 'Ariana', 'Grande', '&', 'Nicki', 'Minaj'],
#  ['Calvin', 'Harris', 'Featuring', 'John', 'Newman'],
#  ['Iggy', 'Azalea', 'Featuring', 'M0'],
#  ['Jeremih', 'Featuring', 'YG'],
#  ['Usher', 'Featuring', 'Juicy', 'J'],
#  ['Iggy', 'Azalea', 'Featuring', 'Rita', 'Ora'],
#  ['Craig', 'Wayne', 'Boyd'],
#  ['Alesso', 'Featuring', 'Tove', 'Lo'],
#  ['Nicki', 'Minaj', 'Featuring', 'Beyonce'],
#  ['Rich', 'Gang', 'Featuring', 'Young', 'Thug', '&', 'Rich', 'Homie', 'Quan'],
#  ['Clean', 'Bandit', 'Featuring', 'Jess', 'Glynne'],
#  ['Trey', 'Songz', 'Featuring', 'Nicki', 'Minaj'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Chris',
#   'Brown,',
#   'August',
#   'Alsina,',
#   'Future',
#   '&',
#   'Jeremih'],
#  ['T.I.', 'Featuring', 'Young', 'Thug'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Nicki', 'Minaj', 'Featuring', 'Skylar', 'Grey'],
#  ['Chris', 'Jamison', '&', 'Adam', 'Levine'],
#  ['Blake', 'Shelton', 'Featuring', 'Ashley', 'Monroe'],
#  ['David', 'Guetta', 'Featuring', 'Sam', 'Martin'],
#  ['Lillywood', '&', 'Robin', 'Schulz'],
#  ['Flo', 'Rida', 'Featuring', 'Sage', 'The', 'Gemini', '&', 'Lookas'],
#  ['Ne-Yo', 'Featuring', 'Juicy', 'J'],
#  ['Matt', 'McAndrew', '&', 'Adam', 'Levine'],
#  ['Maddie', '&', 'Tae'],
#  ['WALK', 'THE', 'MOON'],
#  ['Pitbull', '&', 'Ne-Yo'],
#  ['Nicki', 'Minaj', 'Featuring', 'Ariana', 'Grande'],
#  ['Beyonce',
#   'Featuring',
#   'Nicki',
#   'Minaj',
#   'Or',
#   'Chimamanda',
#   'Ngozi',
#   'Adichie'],
#  ['Kid', 'Ink', 'Featuring', 'Usher', '&', 'Tinashe'],
#  ['Pitbull', 'Featuring', 'John', 'Ryan'],
#  ['Nico', '&', 'Vinz'],
#  ['Taylor', 'Swift', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Jessie', 'J', 'Featuring', '2', 'Chainz'],
#  ['Prince', 'Royce', 'Featuring', 'Snoop', 'Dogg'],
#  ['French', 'Montana', 'Featuring', 'Jeremih'],
#  ['Juicy',
#   'J,',
#   'Wiz',
#   'Khalifa',
#   '&',
#   'Ty',
#   'Dolla',
#   '$ign',
#   'Featuring',
#   'Kill',
#   'The',
#   'Noise',
#   '&',
#   'Madsonik'],
#  ['Kanye', 'West', 'Featuring', 'Paul', 'McCartney'],
#  ['Calvin', 'Harris', 'Featuring', 'Ellie', 'Goulding'],
#  ['Rae', 'Sremmurd', 'Featuring', 'Nicki', 'Minaj', '&', 'Young', 'Thug'],
#  ['G-Eazy', 'Featuring', 'Remo'],
#  ['Chris', 'Brown', '&', 'Tyga'],
#  ['Fall', 'Out', 'Boy'],
#  ['B.o.B', 'Featuring', 'Trey', 'Songz'],
#  ['Omarion', 'Featuring', 'Chris', 'Brown', '&', 'Jhene', 'Aiko'],
#  ['Hoodie', 'Allen', 'Featuring', 'Ed', 'Sheeran'],
#  ['Zac', 'Brown', 'Band'],
#  ['Fall', 'Out', 'Boy'],
#  ['Common', '&', 'John', 'Legend'],
#  ['Wale', 'Featuring', 'Jeremih'],
#  ['Rihanna', '&', 'Kanye', 'West', '&', 'Paul', 'McCartney'],
#  ['Nicki', 'Minaj', 'Featuring', 'Drake', '&', 'Lil', 'Wayne'],
#  ['Fifth', 'Harmony', 'Featuring', 'Kid', 'Ink'],
#  ['Natalie', 'La', 'Rose', 'Featuring', 'Jeremih'],
#  ['Fall', 'Out', 'Boy'],
#  ['Missy', '"Misdemeanor"', 'Elliott'],
#  ['Missy', '"Misdemeanor"', 'Elliott'],
#  ['Big', 'Sean', 'Featuring', 'Drake'],
#  ['Kid', 'Ink', 'Featuring', 'Chris', 'Brown'],
#  ['A-Trak', '+', 'Milo', '&', 'Otis', 'Featuring', 'Rich', 'Kidz'],
#  ['Little', 'Big', 'Town'],
#  ['Drake', 'Featuring', 'PARTYNEXTDOOR'],
#  ['Drake', 'Featuring', 'Lil', 'Wayne'],
#  ['Empire', 'Cast', 'Featuring', 'Jussie', 'Smollett'],
#  ['Florence', '+', 'The', 'Machine'],
#  ['Wiz', 'Khalifa', '&', 'Iggy', 'Azalea'],
#  ['Zedd', 'Featuring', 'Selena', 'Gomez'],
#  ['Empire', 'Cast', 'Featuring', 'Jussie', 'Smollett', '&', 'Yazz'],
#  ['Big', 'Sean', 'Featuring', 'Kanye', 'West'],
#  ['A', 'Thousand', 'Horses'],
#  ['Keith', 'Urban', 'Featuring', 'Eric', 'Church'],
#  ['Big', 'Sean', 'Featuring', 'Kanye', 'West', '&', 'John', 'Legend'],
#  ['Kanye',
#   'West',
#   'Featuring',
#   'Theophilus',
#   'London,',
#   'Allan',
#   'Kingdom',
#   '&',
#   'Paul',
#   'McCartney'],
#  ['Empire', 'Cast', 'Featuring', 'Estelle', '&', 'Jussie', 'Smollett'],
#  ['Carly', 'Rae', 'Jepsen'],
#  ['Cashmere', 'Cat', 'Featuring', 'Ariana', 'Grande'],
#  ['Skrillex', '&', 'Diplo', 'With', 'Justin', 'Bieber'],
#  ['Mumford', '&', 'Sons'],
#  ['Kenny', 'Chesney', 'With', 'Grace', 'Potter'],
#  ['Tim', 'McGraw', 'With', 'Catherine', 'Dunn'],
#  ['Wiz', 'Khalifa', 'Featuring', 'Charlie', 'Puth'],
#  ['twenty', 'one', 'pilots'],
#  ['Kendrick', 'Lamar', 'Featuring', 'George', 'Clinton', '&', 'Thundercat'],
#  ['Kendrick',
#   'Lamar',
#   'Featuring',
#   'Bilal,',
#   'Anna',
#   'Wise',
#   '&',
#   'Thundercat'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Kendrick',
#   'Lamar',
#   'Featuring',
#   'Bilal,',
#   'Anna',
#   'Wise',
#   '&',
#   'Snoop',
#   'Dogg'],
#  ['Nicky', 'Jam', '&', 'Enrique', 'Iglesias'],
#  ['Iggy', 'Azalea', 'Featuring', 'Jennifer', 'Hudson'],
#  ['David',
#   'Guetta',
#   'Featuring',
#   'Nicki',
#   'Minaj,',
#   'Bebe',
#   'Rexha',
#   '&',
#   'Afrojack'],
#  ['Action', 'Bronson', 'Featuring', 'Chance', 'The', 'Rapper'],
#  ['DJ', 'Snake', '&', 'AlunaGeorge'],
#  ['Dillon', 'Francis', '&', 'DJ', 'Snake'],
#  ['Wale', 'Featuring', 'Usher'],
#  ['Ludacris', 'Featuring', 'Miguel'],
#  ['Kid', 'Ink,', 'Tyga,', 'Wale,', 'YG', '&', 'Rich', 'Homie', 'Quan'],
#  ['twenty', 'one', 'pilots'],
#  ['Who', 'Is', 'Fancy'],
#  ['Major', 'Lazer', '&', 'DJ', 'Snake', 'Featuring', 'MO'],
#  ['Kid', 'Ink', 'Featuring', 'DeJ', 'Loaf'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['Bandit', 'Gang', 'Marco', 'Featuring', 'Dro'],
#  ['Rich', 'Homie', 'Quan'],
#  ['Kevin', 'Gates', 'Featuring', 'August', 'Alsina'],
#  ['twenty', 'one', 'pilots'],
#  ['Chedda', 'Da', 'Connect'],
#  ['Britney', 'Spears', '&', 'Iggy', 'Azalea'],
#  ['Shaggy', 'Featuring', 'Mohombi,', 'Faydee,', 'Costi'],
#  ['Jidenna', 'Featuring', 'Roman', 'GianArthur'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Chris',
#   'Brown,',
#   'Lil',
#   'Wayne',
#   '&',
#   'Big',
#   'Sean'],
#  ['Pitbull', 'Featuring', 'Chris', 'Brown'],
#  ['Zedd', 'Featuring', 'Jon', 'Bellion'],
#  ['A$AP', 'Rocky', 'Featuring', 'ScHoolboy', 'Q'],
#  ['Zac', 'Brown', 'Band'],
#  ['Jamie', 'Foxx', 'Featuring', 'Chris', 'Brown'],
#  ['Jeremih', 'Featuring', 'J.', 'Cole'],
#  ['How', 'I', 'Became', 'The', 'Bomb'],
#  ['A$AP',
#   'Rocky',
#   'Featuring',
#   'Rod',
#   'Stewart',
#   'x',
#   'Miguel',
#   'x',
#   'Mark',
#   'Ronson'],
#  ['Tech', 'N9Ne', 'Featuring', '2', 'Chainz', '&', 'B.o.B'],
#  ['Travi$', 'Scott', 'Featuring', 'Future', '&', '2', 'Chainz'],
#  ['Prince', 'Royce', 'Featuring', 'Jennifer', 'Lopez', '&', 'Pitbull'],
#  ['Madonna', 'Featuring', 'Nicki', 'Minaj'],
#  ['Charlie', 'Puth', 'Featuring', 'Meghan', 'Trainor'],
#  ['Sage', 'The', 'Gemini', 'Featuring', 'Nick', 'Jonas'],
#  ['Selena', 'Gomez', 'Featuring', 'A$AP', 'Rocky'],
#  ['Janet', 'Featuring', 'J.', 'Cole'],
#  ['Flo', 'Rida', 'Featuring', 'Robin', 'Thicke', '&', 'Verdine', 'White'],
#  ['Meek', 'Mill', 'Featuring', 'Chris', 'Brown', '&', 'Nicki', 'Minaj'],
#  ['Janelle', 'Monae', '&', 'Jidenna'],
#  ['Fetty', 'Wap', 'Featuring', 'Remy', 'Boyz'],
#  ['Meek', 'Mill', 'Featuring', 'Drake'],
#  ['Big', 'Sean', 'Featuring', 'Chris', 'Brown', '&', 'Ty', 'Dolla', '$ign'],
#  ['Pia', 'Mia', 'Featuring', 'Chris', 'Brown', '&', 'Tyga'],
#  ['Meek', 'Mill', 'Featuring', 'Nicki', 'Minaj'],
#  ['Fetty', 'Wap', 'Featuring', 'Monty'],
#  ['NEEDTOBREATHE', 'Featuring', 'Gavin', 'DeGraw'],
#  ['Meek', 'Mill', 'Featuring', 'Future'],
#  ['Meghan', 'Trainor', 'Featuring', 'John', 'Legend'],
#  ['Eminem', 'Featuring', 'Gwen', 'Stefani'],
#  ['Maddie', '&', 'Tae'],
#  ['5', 'Seconds', 'Of', 'Summer'],
#  ['Calvin', 'Harris', '&', 'Disciples'],
#  ['Future', 'Featuring', 'Drake'],
#  ['R.', 'City', 'Featuring', 'Adam', 'Levine'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Dove',
#   'Cameron,',
#   'Cameron',
#   'Boyce,',
#   'Booboo',
#   'Stewart',
#   '&',
#   'Sofia',
#   'Carson'],
#  ['Disclosure', 'Featuring', 'Sam', 'Smith'],
#  ['The', 'Game', 'Featuring', 'Drake'],
#  ['Lana', 'Del', 'Rey'],
#  ['Dan', '+', 'Shay'],
#  ['Nelly', 'Featuring', 'Jeremih'],
#  ['5', 'Seconds', 'Of', 'Summer'],
#  ['Macklemore',
#   '&',
#   'Ryan',
#   'Lewis',
#   'Featuring',
#   'Eric',
#   'Nally,',
#   'Melle',
#   'Mel,',
#   'Kool',
#   'Moe',
#   'Dee',
#   '&',
#   'Grandmaster',
#   'Caz'],
#  ['Andrew', 'McMahon', 'In', 'The', 'Wilderness'],
#  ['The', 'Weeknd', 'Featuring', 'Lana', 'Del', 'Rey'],
#  ['The', 'Weeknd', 'Featuring', 'Labrinth'],
#  ['The', 'Weeknd', 'Featuring', 'Ed', 'Sheeran'],
#  ['5', 'Seconds', 'Of', 'Summer'],
#  ['Wiz', 'Khalifa', 'Featuring', 'Rae', 'Sremmurd'],
#  ['Ty', 'Dolla', '$ign', 'Featuring', 'Future', '&', 'Rae', 'Sremmurd'],
#  ['Lil', 'Wayne', '&', 'Charlie', 'Puth'],
#  ['Kygo', 'Featuring', 'Conrad'],
#  ['Drake', '&', 'Future'],
#  ['Drake', '&', 'Future'],
#  ['Lil', 'Dicky', 'Featuring', 'Fetty', 'Wap', '&', 'Rich', 'Homie', 'Quan'],
#  ['Drake', '&', 'Future'],
#  ['Drake', '&', 'Future'],
#  ['Drake', '&', 'Future'],
#  ['Drake', '&', 'Future'],
#  ['Drake', '&', 'Future'],
#  ['Naughty', 'Boy', 'Featuring', 'Beyonce', '&', 'Arrow', 'Benjamin'],
#  ['Major', 'Lazer', 'Featuring', 'Ellie', 'Goulding', '&', 'Tarrus', 'Riley'],
#  ['A', 'Great', 'Big', 'World', 'Featuring', 'FUTURISTIC'],
#  ['Drake', '&', 'Future'],
#  ['Drake', '&', 'Future'],
#  ['Fetty', 'Wap', 'Featuring', 'Monty'],
#  ['Rudimental', 'Featuring', 'Ed', 'Sheeran'],
#  ['DeJ', 'Loaf', 'Featuring', 'Big', 'Sean'],
#  ['The', 'Chainsmokers', 'Featuring', 'Rozes'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['G-Eazy', 'x', 'Bebe', 'Rexha'],
#  ['Zac', 'Brown', 'Band'],
#  ['Missy', 'Elliott', 'Featuring', 'Pharrell', 'Williams'],
#  ['Justin', 'Bieber', 'Featuring', 'Halsey'],
#  ['Justin', 'Bieber', 'Featuring', 'Big', 'Sean'],
#  ['Justin', 'Bieber', 'Featuring', 'Travi$', 'Scott'],
#  ['Justin', 'Bieber', 'Featuring', 'Nas'],
#  ['Shawn', 'Mendes', '&', 'Camila', 'Cabello'],
#  ['Luke', 'Bryan', 'Featuring', 'Karen', 'Fairchild'],
#  ['Yo', 'Gotti', 'Featuring', 'Nicki', 'Minaj'],
#  ['PSY', 'Featuring', 'CL'],
#  ['Rick', 'Ross', 'Featuring', 'Chris', 'Brown'],
#  ['G-Eazy', 'Featuring', 'Chris', 'Brown', '&', 'Tory', 'Lanez'],
#  ['Emily', 'Ann', 'Roberts'],
#  ['Jordan', 'Smith', '&', 'Adam', 'Levine'],
#  ['Nat', 'King', 'Cole'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Robin', 'Schulz', 'Featuring', 'Francesco', 'Yates'],
#  ['Queen', '&', 'David', 'Bowie'],
#  ['David', 'Guetta', 'Featuring', 'Sia', '&', 'Fetty', 'Wap'],
#  ['Empire', 'Of', 'The', 'Sun'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['DJ', 'Snake', 'Featuring', 'Bipolar', 'Sunshine'],
#  ['Rihanna', 'Featuring', 'Drake'],
#  ['Wiz', 'Khalifa', 'Featuring', 'Travi$', 'Scott'],
#  ['Curren$Y', 'Featuring', 'August', 'Alsina', '&', 'Lil', 'Wayne'],
#  ['Charlie', 'Puth', 'Featuring', 'Selena', 'Gomez'],
#  ['Kevin',
#   'Gates',
#   'Featuring',
#   'Trey',
#   'Songz,',
#   'Ty',
#   'Dolla',
#   '$ign',
#   '&',
#   'Jamie',
#   'Foxx'],
#  ['Future', 'Featuring', 'The', 'Weeknd'],
#  ['The', 'Chainsmokers', 'Featuring', 'Daya'],
#  ['Sia', 'Featuring', 'Sean', 'Paul'],
#  ['Zara', 'Larsson', '&', 'MNEK'],
#  ['DJ', 'Luke', 'Nasty'],
#  ['Chris', 'Young', 'Duet', 'With', 'Cassadee', 'Pope'],
#  ['Kid', 'Ink', 'Featuring', 'Fetty', 'Wap'],
#  ['Ty', 'Dolla', '$ign', 'Featuring', 'E-40'],
#  ['O.T.', 'Genasis', 'Featuring', 'Young', 'Dolph'],
#  ['Belly', 'Featuring', 'The', 'Weeknd'],
#  ['Fifth', 'Harmony', 'Featuring', 'Ty', 'Dolla', '$ign'],
#  ['Flo', 'Rida', 'Featuring', 'Jason', 'Derulo'],
#  ['Zendaya', 'Featuring', 'Chris', 'Brown'],
#  ['2', 'Chainz', 'Featuring', 'Lil', 'Wayne'],
#  ['twenty', 'one', 'pilots'],
#  ['Major', 'Lazer', 'Featuring', 'Nyla', '&', 'Fuse', 'ODG'],
#  ['Jonas', 'Blue', 'Featuring', 'Dakota'],
#  ['Dreezy', 'Featuring', 'Jeremih'],
#  ['Nick', 'Jonas', 'Featuring', 'Tove', 'Lo'],
#  ['Fat',
#   'Joe,',
#   'Remy',
#   'Ma',
#   '&',
#   'Jay',
#   'Z',
#   'Featuring',
#   'French',
#   'Montana',
#   '&',
#   'Infared'],
#  ['A$AP', 'Ferg', 'Featuring', 'Future'],
#  ['Drake', 'Featuring', 'The', 'Throne'],
#  ['Drake', 'Featuring', 'WizKid', '&', 'Kyla'],
#  ['PARTYNEXTDOOR', 'Featuring', 'Drake'],
#  ['Flume', 'Featuring', 'Kai'],
#  ['Pitbull', 'Featuring', 'Enrique', 'Iglesias'],
#  ['Yo', 'Gotti', 'Featuring', 'E-40'],
#  ['Prince', 'And', 'The', 'Revolution'],
#  ['Prince', 'And', 'The', 'Revolution'],
#  ['Prince', 'And', 'The', 'Revolution'],
#  ['gnash', 'Featuring', 'Olivia', "O'Brien"],
#  ['Grace', 'Featuring', 'G-Eazy'],
#  ['Ariana', 'Grande', 'Featuring', 'Lil', 'Wayne'],
#  ['Beyonce', 'Featuring', 'The', 'Weeknd'],
#  ['Beyonce', 'Featuring', 'Jack', 'White'],
#  ['Prince', 'And', 'The', 'Revolution'],
#  ['Beyonce', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Prince', 'And', 'The', 'Revolution'],
#  ['Beyonce', 'Featuring', 'James', 'Blake'],
#  ['Calvin', 'Harris', 'Featuring', 'Rihanna'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Ghost', 'Town', "DJ's"],
#  ['Drake', 'Featuring', 'Future'],
#  ['Drake', 'Featuring', 'PARTYNEXTDOOR'],
#  ['Drake', 'Featuring', 'Rihanna'],
#  ['Drake', 'Featuring', 'Pimp', 'C', '&', 'dvsn'],
#  ['Zedd', '&', 'Kesha'],
#  ['Blake', 'Shelton', 'Featuring', 'Gwen', 'Stefani'],
#  ['Keith', 'Urban', 'Featuring', 'Carrie', 'Underwood'],
#  ['Chance', 'The', 'Rapper', 'Featuring', 'Lil', 'Wayne', '&', '2', 'Chainz'],
#  ['ScHoolboy', 'Q', 'Featuring', 'Kanye', 'West'],
#  ['Chance', 'The', 'Rapper', 'Featuring', 'Ty', 'Dolla', '$ign'],
#  ['Dan', '+', 'Shay'],
#  ['Dierks', 'Bentley', 'Featuring', 'Elle', 'King'],
#  ['DJ', 'Khaled', 'Featuring', 'Drake'],
#  ['Mike', 'WiLL', 'Made-It', 'x', 'Rihanna'],
#  ['Kanye',
#   'West,',
#   'Gucci',
#   'Mane,',
#   'Big',
#   'Sean,',
#   '2',
#   'Chainz,',
#   'Travi$',
#   'Scott,',
#   'Yo',
#   'Gotti,',
#   'Quavo,',
#   'Desiigner'],
#  ['D.R.A.M.', 'Featuring', 'Lil', 'Yachty'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['twenty', 'one', 'pilots'],
#  ['Red', 'Hot', 'Chili', 'Peppers'],
#  ['Fifth', 'Harmony', 'Featuring', 'Fetty', 'Wap'],
#  ['Broadway', 'For', 'Orlando'],
#  ['YG', 'Featuring', 'Drake', '&', 'Kamaiyah'],
#  ['Lil',
#   'Wayne,',
#   'Wiz',
#   'Khalifa',
#   '&',
#   'Imagine',
#   'Dragons',
#   'With',
#   'Logic',
#   '&',
#   'Ty',
#   'Dolla',
#   '$ign',
#   'Feat.',
#   'X',
#   'Ambassadors'],
#  ['DJ', 'Khaled', 'Featuring', 'Jay', 'Z', '&', 'Future'],
#  ['Usher', 'Featuring', 'Young', 'Thug'],
#  ['French', 'Montana', 'Featuring', 'Kodak', 'Black'],
#  ['Jennifer', 'Lopez', '&', 'Lin-Manuel', 'Miranda'],
#  ['Enrique', 'Iglesias', 'Feat.', 'Wisin', 'or', 'Tinashe', '&', 'Javada'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Marc', 'E.', 'Bassy', 'Featuring', 'G-Eazy'],
#  ['Carlos', 'Vives', '&', 'Shakira'],
#  ['Britney', 'Spears', 'Featuring', 'G-Eazy'],
#  ['5', 'Seconds', 'Of', 'Summer'],
#  ['French', 'Montana', 'Featuring', 'Drake'],
#  ['Major', 'Lazer', 'Featuring', 'Justin', 'Bieber', '&', 'MO'],
#  ['Skrillex', '&', 'Rick', 'Ross'],
#  ['Gucci', 'Mane', '&', 'Drake'],
#  ['Gucci', 'Mane', 'Featuring', 'Kanye', 'West'],
#  ['Kungs', 'vs', "Cookin'", 'On', '3', 'Burners'],
#  ['Zac', 'Brown', 'Band'],
#  ['The', 'Chainsmokers', 'Featuring', 'Halsey'],
#  ['Kenny', 'Chesney', 'Featuring', 'P!nk'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Big',
#   'Sean,',
#   'Kendrick',
#   'Lamar',
#   '&',
#   'Betty',
#   'Wright'],
#  ['Hailee', 'Steinfeld', '&', 'Grey', 'Featuring', 'Zedd'],
#  ['Rob', '$tone', 'Featuring', 'J.', 'Davi$', '&', 'Spooks'],
#  ['DJ', 'Snake', 'Featuring', 'Justin', 'Bieber'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Nicki',
#   'Minaj,',
#   'Chris',
#   'Brown,',
#   'August',
#   'Alsina,',
#   'Jeremih,',
#   'Future',
#   '&',
#   'Rick',
#   'Ross'],
#  ['Young', 'Thug', 'And', 'Travis', 'Scott', 'Featuring', 'Quavo'],
#  ['Martin', 'Garrix', '&', 'Bebe', 'Rexha'],
#  ['DJ', 'Drama', 'Featuring', 'Chris', 'Brown,', 'Skeme', '&', 'Lyquin'],
#  ['DJ', 'ESCO', 'Featuring', 'Future', '&', 'Lil', 'Uzi', 'Vert'],
#  ['William', 'Michael', 'Morgan'],
#  ['Ariana', 'Grande', 'Featuring', 'Nicki', 'Minaj'],
#  ['Florida', 'Georgia', 'Line', 'Featuring', 'Tim', 'McGraw'],
#  ['Sia', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Post', 'Malone', 'Featuring', 'Justin', 'Bieber'],
#  ['Rae', 'Sremmurd', 'Featuring', 'Gucci', 'Mane'],
#  ['21', 'Savage', '&', 'Metro', 'Boomin', 'Featuring', 'Future'],
#  ['Artists', 'Of', 'Then,', 'Now', '&', 'Forever'],
#  ['The', 'Weeknd', 'Featuring', 'Daft', 'Punk'],
#  ['Zay', 'Hilfigerrr', '&', 'Zayion', 'McCall'],
#  ['YFN', 'Lucci', 'Featuring', 'Migos', '&', 'Trouble'],
#  ['twenty', 'one', 'pilots'],
#  ['Fitz', 'And', 'The', 'Tantrums'],
#  ['Frenship', '&', 'Emily', 'Warren'],
#  ['The', 'Chainsmokers', 'Featuring', 'Phoebe', 'Ryan'],
#  ['Flume', 'Featuring', 'Tove', 'Lo'],
#  ['Solange', 'Featuring', 'Sampha'],
#  ['The', 'Game', 'Featuring', 'Jeremih'],
#  ['Maroon', '5', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Machine', 'Gun', 'Kelly', 'x', 'Camila', 'Cabello'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ['Drake', 'Featuring', '21', 'Savage'],
#  ['21', 'Savage', '&', 'Metro', 'Boomin'],
#  ['Pitbull', 'Featuring', 'Flo', 'Rida', '&', 'LunchMoney', 'Lewis'],
#  ['Meek', 'Mill', 'Featuring', 'Tory', 'Lanez'],
#  ['Little', 'Big', 'Town'],
#  ['Meek', 'Mill', 'Featuring', 'Lil', 'Uzi', 'Vert', '&', 'Nicki', 'Minaj'],
#  ['Meek', 'Mill', 'Featuring', 'Young', 'Thug', '&', '21', 'Savage'],
#  ['Meek', 'Mill', 'Featuring', 'Quavo'],
#  ['Shakira', 'Featuring', 'Maluma'],
#  ['Future', 'Featuring', 'Drake'],
#  ['The', 'Chainsmokers', 'Featuring', 'XYLO'],
#  ['Eric', 'Church', 'Featuring', 'Rhiannon', 'Giddens'],
#  ['Migos', 'Featuring', 'Lil', 'Uzi', 'Vert'],
#  ['A', 'Tribe', 'Called', 'Quest'],
#  ['The', 'Weeknd', 'Featuring', 'Daft', 'Punk'],
#  ['Britney', 'Spears', 'Featuring', 'Tinashe'],
#  ['The', 'Weeknd', 'Featuring', 'Kendrick', 'Lamar'],
#  ['The', 'Weeknd', 'Featuring', 'Future'],
#  ['The', 'Weeknd', 'Featuring', 'Lana', 'Del', 'Rey'],
#  ['Opetaia', "Foa'i", '&', 'Lin-Manuel', 'Miranda'],
#  ['Noah', 'Cyrus', 'Featuring', 'Labrinth'],
#  ['Nicki', 'Minaj', 'X', 'Mike', 'WiLL', 'Made-It'],
#  ['gnash', 'Featuring', 'Johnny', 'Yukon'],
#  ['Clean', 'Bandit', 'Featuring', 'Sean', 'Paul', '&', 'Anne-Marie'],
#  ['Zayn', '/', 'Taylor', 'Swift'],
#  ['Steve', 'Aoki', '&', 'Louis', 'Tomlinson'],
#  ['Post', 'Malone', 'Featuring', 'Quavo'],
#  ['Gucci', 'Mane', 'Featuring', 'Drake'],
#  ['Chris', 'Brown', 'Featuring', 'Usher', '&', 'Gucci', 'Mane'],
#  ['DJ', 'Luke', 'Nasty'],
#  ['Wham!', 'Featuring', 'George', 'Michael'],
#  ['KYLE', 'Featuring', 'Lil', 'Yachty'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie', 'Featuring', 'DJ', 'SPINKING'],
#  ['Chris', 'Young', 'Featuring', 'Vince', 'Gill'],
#  ['Luis', 'Fonsi', '&', 'Daddy', 'Yankee', 'Featuring', 'Justin', 'Bieber'],
#  ['2', 'Chainz', 'x', 'Gucci', 'Mane', 'x', 'Quavo'],
#  ['Wale', 'Featuring', 'Lil', 'Wayne'],
#  ['Migos', 'Featuring', 'Gucci', 'Mane'],
#  ['Migos', 'Featuring', 'Travis', 'Scott'],
#  ['Major', 'Lazer', 'Featuring', 'PARTYNEXTDOOR', '&', 'Nicki', 'Minaj'],
#  ['Missy', 'Elliott', 'Featuring', 'Lamb'],
#  ['Martin', 'Garrix', '&', 'Dua', 'Lipa'],
#  ['Migos', 'Featuring', 'DJ', 'Khaled'],
#  ['G-Eazy', 'Featuring', 'Marc', 'E.', 'Bassy'],
#  ['Big', 'Sean', 'Featuring', 'Eminem'],
#  ['Zac', 'Brown', 'Band'],
#  ['Big', 'Sean', 'Featuring', 'Migos'],
#  ['Ariana', 'Grande', '&', 'John', 'Legend'],
#  ['Mariah', 'Carey', 'Featuring', 'YG'],
#  ['Sage', 'The', 'Gemini'],
#  ['Big', 'Sean', 'Featuring', 'Jeremih'],
#  ['Katy', 'Perry', 'Featuring', 'Skip', 'Marley'],
#  ['Maroon', '5', 'Featuring', 'Future'],
#  ['Nick', 'Jonas', '&', 'Nicki', 'Minaj'],
#  ['DJ', 'Khaled', 'Featuring', 'Beyonce', '&', 'JAY', 'Z'],
#  ['Ariana', 'Grande', 'Featuring', 'Future'],
#  ['Ayo', '&', 'Teo'],
#  ['DJ', 'Suede', 'The', 'Remix', 'God'],
#  ['Kygo', 'x', 'Selena', 'Gomez'],
#  ['Lana', 'Del', 'Rey'],
#  ['Linkin', 'Park', 'Featuring', 'Kiiara'],
#  ['The', 'Chainsmokers', '&', 'Coldplay'],
#  ['Zedd', '&', 'Alessia', 'Cara'],
#  ['Calvin', 'Harris', 'Featuring', 'Frank', 'Ocean', '&', 'Migos'],
#  ['Future', 'Featuring', 'Rihanna'],
#  ['Future', 'Featuring', 'The', 'Weeknd'],
#  ['Gucci', 'Mane', '&', 'Nicki', 'Minaj'],
#  ['Florida', 'Georgia', 'Line', 'Featuring', 'Backstreet', 'Boys'],
#  ['Nicki', 'Minaj,', 'Drake', '&', 'Lil', 'Wayne'],
#  ['Nicki', 'Minaj', '&', 'Lil', 'Wayne'],
#  ['Drake', 'Featuring', 'Quavo', '&', 'Travis', 'Scott'],
#  ['Drake', 'Featuring', '2', 'Chainz', '&', 'Young', 'Thug'],
#  ['Drake', 'Featuring', 'Giggs'],
#  ['Drake', 'Featuring', 'Jorja', 'Smith', '&', 'Black', 'Coffee'],
#  ['Drake', 'Featuring', 'Giggs'],
#  ['Drake', 'Featuring', 'Sampha'],
#  ['Drake', 'Featuring', 'Kanye', 'West'],
#  ['Drake', 'Featuring', 'Young', 'Thug'],
#  ['Drake', 'Featuring', 'PARTYNEXTDOOR'],
#  ['Machine', 'Gun', 'Kelly', 'Featuring', 'Hailee', 'Steinfeld'],
#  ['Rick', 'Ross', 'Featuring', 'Young', 'Thug', '&', 'Wale'],
#  ['Jason',
#   'Derulo',
#   'Featuring',
#   'Nicki',
#   'Minaj',
#   '&',
#   'Ty',
#   'Dolla',
#   '$ign'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Tim', 'McGraw', '&', 'Faith', 'Hill'],
#  ['Zayn', 'Featuring', 'PARTYNEXTDOOR'],
#  ['Thomas', 'Rhett', 'Featuring', 'Maren', 'Morris'],
#  ['Enrique',
#   'Iglesias',
#   'Featuring',
#   'Descemer',
#   'Bueno,',
#   'Zion',
#   '&',
#   'Lennox',
#   'Or',
#   'Sean',
#   'Paul'],
#  ['Kodak', 'Black', 'Featuring', 'Future'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie', 'Featuring', 'Kodak', 'Black'],
#  ['Calvin',
#   'Harris',
#   'Featuring',
#   'Young',
#   'Thug,',
#   'Pharrell',
#   'Williams',
#   '&',
#   'Ariana',
#   'Grande'],
#  ['Dan', '+', 'Shay'],
#  ['French', 'Montana', 'Featuring', 'Swae', 'Lee'],
#  ['YFN', 'Lucci', 'Featuring', 'PnB', 'Rock'],
#  ['Flo', 'Rida', '&', '99', 'Percent'],
#  ['Kendrick', 'Lamar', 'Featuring', 'Rihanna'],
#  ['Kendrick', 'Lamar', 'Featuring', 'Zacari'],
#  ['Kendrick', 'Lamar', 'Featuring', 'U2'],
#  ['G-Eazy', '&', 'Kehlani'],
#  ['Lil', 'Yachty', 'Featuring', 'Migos'],
#  ['Logic', 'Featuring', 'Damian', 'Lemar', 'Hudson'],
#  ['Lana', 'Del', 'Rey', 'Featuring', 'The', 'Weeknd'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Justin',
#   'Bieber,',
#   'Quavo,',
#   'Chance',
#   'The',
#   'Rapper',
#   '&',
#   'Lil',
#   'Wayne'],
#  ['Logic', 'Featuring', 'Alessia', 'Cara', '&', 'Khalid'],
#  ['Kygo', '&', 'Ellie', 'Goulding'],
#  ['Katy', 'Perry', 'Featuring', 'Migos'],
#  ['Playboi', 'Carti', 'Featuring', 'Lil', 'Uzi', 'Vert'],
#  ['Calvin', 'Harris', 'Featuring', 'Future', '&', 'Khalid'],
#  ['Cheat', 'Codes', 'Featuring', 'Demi', 'Lovato'],
#  ['Liam', 'Payne', 'Featuring', 'Quavo'],
#  ['Katy', 'Perry', 'Featuring', 'Nicki', 'Minaj'],
#  ['Gucci', 'Mane', 'Featuring', 'Offset'],
#  ['Martin', 'Garrix', 'x', 'Troye', 'Sivan'],
#  ['Halsey', 'Featuring', 'Lauren', 'Jauregui'],
#  ['Fifth', 'Harmony', 'Featuring', 'Gucci', 'Mane'],
#  ['DJ', 'Khaled', 'Featuring', 'Drake'],
#  ['2', 'Chainz', 'Featuring', 'Travis', 'Scott'],
#  ['Meek', 'Mill', 'Featuring', 'Chris', 'Brown', '&', 'Ty', 'Dolla', '$ign'],
#  ['Major',
#   'Lazer',
#   'Featuring',
#   'Travis',
#   'Scott,',
#   'Camila',
#   'Cabello',
#   '&',
#   'Quavo'],
#  ['Jake', 'Paul', 'Featuring', 'Team', '10'],
#  ['David', 'Guetta', 'Featuring', 'Justin', 'Bieber'],
#  ['SZA', 'Featuring', 'Travis', 'Scott'],
#  ['Wisin', 'Featuring', 'Ozuna'],
#  ['Kane', 'Brown', 'Featuring', 'Lauren', 'Alaina'],
#  ['2',
#   'Chainz',
#   'Featuring',
#   'Ty',
#   'Dolla',
#   '$ign,',
#   'Trey',
#   'Songz',
#   '&',
#   'Jhene',
#   'Aiko'],
#  ['DJ', 'Khaled', 'Featuring', 'Rihanna', '&', 'Bryson', 'Tiller'],
#  ['Calvin',
#   'Harris',
#   'Featuring',
#   'Pharrell',
#   'Williams,',
#   'Katy',
#   'Perry',
#   '&',
#   'Big',
#   'Sean'],
#  ['Young', 'Thug', 'Featuring', 'Future'],
#  ['Portugal.', 'The', 'Man'],
#  ['Plies', 'Featuring', 'Kodak', 'Black'],
#  ['DJ',
#   'Khaled',
#   '&',
#   'Calvin',
#   'Harris',
#   'Featuring',
#   'Travis',
#   'Scott',
#   '&',
#   'Jeremih'],
#  ['Metro', 'Boomin', 'Featuring', 'Offset', '&', 'Drake'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Travis',
#   'Scott,',
#   'Rick',
#   'Ross',
#   '&',
#   'Big',
#   'Sean'],
#  ['GoldLink', 'Featuring', 'Brent', 'Faiyaz', '&', 'Shy', 'Glizzy'],
#  ['J', 'Balvin', '&', 'Willy', 'William', 'Featuring', 'Beyonce'],
#  ['Yo', 'Gotti', 'Featuring', 'Nicki', 'Minaj'],
#  ['Tyler,', 'The', 'Creator'],
#  ['Future', 'Featuring', 'YG'],
#  ['JAY-Z', 'Featuring', 'Damian', '"Jr.', 'Gong"', 'Marely'],
#  ['JAY-Z', 'Featuring', 'Beyonce'],
#  ['JAY-Z', 'Featuring', 'Gloria', 'Carter'],
#  ['JAY-Z', 'Featuring', 'Frank', 'Ocean'],
#  ['Macklemore', 'Featuring', 'Skylar', 'Grey'],
#  ['Zedd', '&', 'Liam', 'Payne'],
#  ['Selena', 'Gomez', 'Featuring', 'Gucci', 'Mane'],
#  ['French', 'Montana', 'Featuring', 'The', 'Weeknd', '&', 'Max', 'B'],
#  ['Jake', 'Paul', '&', 'Erika', 'Costell', 'Featuring', 'Uncle', 'Kade'],
#  ['Kesha', 'Featuring', 'The', 'Dap-Kings', 'Horns'],
#  ['Louis',
#   'Tomlinson',
#   'Featuring',
#   'Bebe',
#   'Rexha',
#   '&',
#   'Digital',
#   'Farm',
#   'Animals'],
#  ['China', 'Anne', 'McClain,', 'Thomas', 'Doherty', '&', 'Dylan', 'Playfair'],
#  ['Descendants', '2', 'Cast'],
#  ['Meek', 'Mill', 'Featuring', 'Young', 'Thug'],
#  ['Meek', 'Mill', 'Featuring', 'Lil', 'Uzi', 'Vert'],
#  ['Future', 'Featuring', 'Nicki', 'Minaj'],
#  ['Camila', 'Cabello', 'Featuring', 'Quavo'],
#  ['Sofia',
#   'Carson,',
#   'Cameron',
#   'Boyce,',
#   'Booboo',
#   'Stewart',
#   '&',
#   'Mitchell',
#   'Hope'],
#  ['Camila', 'Cabello', 'Featuring', 'Young', 'Thug'],
#  ['Marshmello', 'Featuring', 'Khalid'],
#  ['Wiz', 'Khalifa', 'Featuring', 'Ty', 'Dolla', '$ign'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['Justin', 'Bieber', '+', 'BloodPop'],
#  ['Gucci', 'Mane', 'Featuring', 'Migos'],
#  ['Kodak', 'Black', 'Featuring', 'XXXTENTACION'],
#  ['RiceGum', 'Featuring', 'Alissa', 'Violet'],
#  ['Lil', 'Uzi', 'Vert', 'Featuring', 'Nicki', 'Minaj'],
#  ['XXXTENTACION', 'Featuring', 'Trippie', 'Redd'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Maroon', '5', 'Featuring', 'SZA'],
#  ['Lil', 'Uzi', 'Vert', 'Featuring', 'Pharrell', 'Williams'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Lil', 'Uzi', 'Vert', 'Featuring', 'The', 'Weeknd'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Miguel', 'Featuring', 'Travis', 'Scott'],
#  ['Zayn', 'Featuring', 'Sia'],
#  ['G-Eazy', 'Featuring', 'A$AP', 'Rocky', '&', 'Cardi', 'B'],
#  ['Chris',
#   'Brown',
#   'Featuring',
#   'Yo',
#   'Gotti,',
#   'A',
#   'Boogie',
#   'Wit',
#   'da',
#   'Hoodie',
#   '&',
#   'Kodak',
#   'Black'],
#  ['Hailee',
#   'Steinfeld',
#   '&',
#   'Alesso',
#   'Featuring',
#   'Florida',
#   'Georgia',
#   'Line',
#   '&',
#   'Watt'],
#  ['Post', 'Malone', 'Featuring', '21', 'Savage'],
#  ['Gucci', 'Mane', 'Featuring', 'The', 'Weeknd'],
#  ['Lorde', 'Featuring', 'Khalid,', 'Post', 'Malone', '&', 'SZA'],
#  ['Macklemore', 'Featuring', 'Kesha'],
#  ['A$AP', 'Ferg', 'Featuring', 'Nicki', 'Minaj'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie', 'Featuring', '21', 'Savage'],
#  ['A',
#   'Boogie',
#   'Wit',
#   'da',
#   'Hoodie',
#   'Featuring',
#   'PnB',
#   'Rock',
#   '&',
#   'YoungBoy',
#   'Never',
#   'Broke',
#   'Again'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Lin-Manuel', 'Miranda', 'Featuring', 'Artists', 'For', 'Puerto', 'Rico'],
#  ['Sam', 'Smith', 'Featuring', 'Logic'],
#  ['Maren', 'Morris', 'Featuring', 'Vince', 'Gill'],
#  ['MAX', 'Featuring', 'gnash'],
#  ['Quavo,', 'Takeoff', '&', 'Offset'],
#  ['Chris', 'Brown', 'Featuring', 'Future', '&', 'Young', 'Thug'],
#  ['Gucci', 'Mane', 'Featuring', 'Slim', 'Jxmmi', '&', 'Young', 'Dolph'],
#  ['Becky', 'G', 'Featuring', 'Bad', 'Bunny'],
#  ['Future', '&', 'Young', 'Thug', 'Featuring', 'Offset'],
#  ['Bebe', 'Rexha', '&', 'Florida', 'Georgia', 'Line'],
#  ['Future', '&', 'Young', 'Thug'],
#  ['Future', '&', 'Young', 'Thug'],
#  ['Selena', 'Gomez', 'X', 'Marshmello'],
#  ['Future', '&', 'Young', 'Thug'],
#  ['Migos,', 'Nicki', 'Minaj', '&', 'Cardi', 'B'],
#  ['21',
#   'Savage,',
#   'Offset',
#   '&',
#   'Metro',
#   'Boomin',
#   'Featuring',
#   'Travis',
#   'Scott'],
#  ['Offset', '&', 'Metro', 'Boomin'],
#  ['21', 'Savage,', 'Offset', '&', 'Metro', 'Boomin', 'Featuring', 'Quavo'],
#  ['21', 'Savage', '&', 'Metro', 'Boomin'],
#  ['N*E*R*D', '&', 'Rihanna'],
#  ['Big', 'Sean', '&', 'Metro', 'Boomin', 'Featuring', '21', 'Savage'],
#  ['21', 'Savage,', 'Offset', '&', 'Metro', 'Boomin'],
#  ['Offset', '&', 'Metro', 'Boomin'],
#  ['Eminem', 'Featuring', 'Beyonce'],
#  ['NAV', 'Featuring', 'Lil', 'Uzi', 'Vert'],
#  ['Famous', 'Dex', 'Featuring', 'A$AP', 'Rocky'],
#  ['Luis', 'Fonsi', '&', 'Demi', 'Lovato'],
#  ['Taylor', 'Swift', 'Featuring', 'Ed', 'Sheeran', '&', 'Future'],
#  ['Machine', 'Gun', 'Kelly,', 'X', 'Ambassadors', '&', 'Bebe', 'Rexha'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['Tim', 'McGraw', '&', 'Faith', 'Hill'],
#  ['Calvin', 'Harris', 'Featuring', 'Kehlani', '&', 'Lil', 'Yachty'],
#  ['BTS', 'Featuring', 'Desiigner'],
#  ['Kodak', 'Black', 'Featuring', 'Lil', 'Wayne'],
#  ['Farruko,',
#   'Nicki',
#   'Minaj,',
#   'Bad',
#   'Bunny,',
#   '21',
#   'Savage',
#   '&',
#   'Rvssian'],
#  ['Shakira', 'Featuring', 'Nicky', 'Jam'],
#  ['G-Eazy', '&', 'Halsey'],
#  ['Romeo', 'Santos', 'Featuring', 'Nicky', 'Jam', '&', 'Daddy', 'Yankee'],
#  ['Natti', 'Natasha', 'x', 'Ozuna'],
#  ['Big', 'Sean', '&', 'Metro', 'Boomin', 'Featuring', 'Travis', 'Scott'],
#  ['Trippie', 'Redd', 'Featuring', 'Travis', 'Scott'],
#  ['Migos', '&', 'Marshmello'],
#  ['Cardi', 'B', 'Featuring', '21', 'Savage'],
#  ['Eminem', 'Featuring', 'Ed', 'Sheeran'],
#  ['Ozuna', 'x', 'Cardi', 'B'],
#  ['Huncho', 'Jack', 'Featuring', 'Takeoff'],
#  ['Imagine', 'Dragons', '+', 'Khalid'],
#  ['Quavo', '&', 'Lil', 'Yachty'],
#  ['Huncho', 'Jack', 'Featuring', 'Offset'],
#  ['Bruno', 'Mars', '&', 'Cardi', 'B'],
#  ['WALK', 'THE', 'MOON'],
#  ['Keala', 'Settle', '&', 'The', 'Greatest', 'Showman', 'Ensemble'],
#  ['Zac', 'Efron', '&', 'Zendaya'],
#  ['Maluma', 'X', 'Nego', 'do', 'Borel'],
#  ['Hugh',
#   'Jackman,',
#   'Keala',
#   'Settle,',
#   'Zac',
#   'Efron,',
#   'Zendaya',
#   '&',
#   'The',
#   'Greatest',
#   'Showman',
#   'Ensemble'],
#  ['Sofi',
#   'Tukker',
#   'Featuring',
#   'NERVO,',
#   'The',
#   'Knocks',
#   '&',
#   'Alisa',
#   'Ueno'],
#  ['Kendrick', 'Lamar', '&', 'SZA'],
#  ['Liam', 'Payne', '&', 'Rita', 'Ora'],
#  ['Lil', 'Skies', 'Featuring', 'Landon', 'Cube'],
#  ['Clean', 'Bandit', 'Featuring', 'Julia', 'Michaels'],
#  ['Lil', 'Skies', 'Featuring', 'Landon', 'Cube'],
#  ['Carrie', 'Underwood', 'Featuring', 'Ludacris'],
#  ['6ix9ine,', 'Fetty', 'Wap', '&', 'A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['Dan', '+', 'Shay'],
#  ['Jay', 'Rock,', 'Kendrick', 'Lamar,', 'Future', '&', 'James', 'Blake'],
#  ['Enrique', 'Iglesias', 'Featuring', 'Bad', 'Bunny'],
#  ['Justin', 'Timberlake', 'Featuring', 'Chris', 'Stapleton'],
#  ['Migos', 'Featuring', 'Drake'],
#  ['Zedd,', 'Maren', 'Morris', '&', 'Grey'],
#  ['Migos', 'Featuring', '21', 'Savage'],
#  ['Migos', 'Featuring', 'Post', 'Malone'],
#  ['Migos',
#   'Featuring',
#   'Travis',
#   'Scott,',
#   'Ty',
#   'Dolla',
#   '$ign',
#   '&',
#   'Big',
#   'Sean'],
#  ['Rich', 'The', 'Kid', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Ozuna', '&', 'Romeo', 'Santos'],
#  ['Migos', 'Featuring', 'Gucci', 'Mane'],
#  ['The', 'Weeknd', '&', 'Kendrick', 'Lamar'],
#  ['Jacquees', 'X', 'Dej', 'Loaf'],
#  ['BlocBoy', 'JB', 'Featuring', 'Drake'],
#  ['ScHoolboy', 'Q,', '2', 'Chainz', '&', 'Saudi'],
#  ['Rich', 'The', 'Kid'],
#  ['Khalid', '&', 'Swae', 'Lee'],
#  ['SOB', 'X', 'RBE'],
#  ['Kendrick', 'Lamar', '&', 'Travis', 'Scott'],
#  ['Marshmello', '&', 'Anne-Marie'],
#  ['Khalid', '&', 'Normani'],
#  ['Daniel', 'Caesar', 'Featuring', 'Kali', 'Uchis'],
#  ['Post', 'Malone', 'Featuring', 'Ty', 'Dolla', '$ign'],
#  ['5', 'Seconds', 'Of', 'Summer'],
#  ['6ix9ine', 'Featuring', 'Tory', 'Lanez', '&', 'Young', 'Thug'],
#  ['DJ', 'Khaled', 'Featuring', 'JAY', 'Z,', 'Future', '&', 'B'],
#  ['Logic', '&', 'Marshmello'],
#  ['Rae', 'Sremmurd', '&', 'Juicy', 'J'],
#  ['Nicky', 'Jam', 'x', 'J', 'Balvin'],
#  ['Joyner', 'Lucas', '&', 'Chris', 'Brown'],
#  ['Jhene', 'Aiko', 'Featuring', 'Swae', 'Lee', 'Or', 'Rae', 'Sremmurd'],
#  ['Logic', 'Featuring', 'Wiz', 'Khalifa'],
#  ['Lil', 'Yachty', 'Featuring', 'NBA', 'YoungBoy'],
#  ['Lil', 'Yachty', 'Featuring', 'Trippie', 'Redd'],
#  ['Logic', 'Featuring', 'Big', 'Sean'],
#  ['Lil', 'Yachty', 'Featuring', 'Ugly', 'God'],
#  ['Logic', 'Featuring', 'Young', 'Sinatra'],
#  ['Lil', 'Dicky', 'Featuring', 'Chris', 'Brown'],
#  ['Lin-Manuel', 'Miranda', '&', 'Ben', 'Platt'],
#  ['XXXTENTACION', 'Featuring', 'Joey', 'Bada$$'],
#  ['Foster', 'The', 'People'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['Shawn', 'Mendes', 'X', 'Zedd'],
#  ['Morgan', 'Wallen', 'Featuring', 'Florida', 'Georgia', 'Line'],
#  ['The', 'Weeknd', 'Featuring', 'Gesaffelstein'],
#  ['The', 'Weeknd', 'Featuring', 'Gesaffelstein'],
#  ['Tyler,', 'The', 'Creator'],
#  ['Chris', 'Lane', 'Featuring', 'Tori', 'Kelly'],
#  ['2', 'Chainz', 'Featuring', 'YG', '&', 'Offset'],
#  ['Cardi', 'B,', 'Bad', 'Bunny', '&', 'J', 'Balvin'],
#  ['Cardi', 'B', 'Featuring', 'Migos'],
#  ['Cardi', 'B', 'Featuring', 'SZA'],
#  ['Cardi', 'B', 'Featuring', 'Kehlani'],
#  ['Cardi', 'B', 'Featuring', 'Chance', 'The', 'Rapper'],
#  ['Cardi', 'B', '&', 'YG'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['Calvin', 'Harris', '&', 'Dua', 'Lipa'],
#  ['A$AP', 'Rocky', 'Featuring', 'Moby'],
#  ['Halsey', 'Featuring', 'Big', 'Sean', '&', 'Stefflon', 'Don'],
#  ['Swae', 'Lee', 'Featuring', 'Slim', 'Jxmmi'],
#  ['Young', 'Thug', 'Featuring', 'Nicki', 'Minaj'],
#  ['J.', 'Cole', 'Featuring', 'kiLL', 'edward'],
#  ['J.', 'Cole', 'Featuring', 'kiLL', 'edward'],
#  ['Khalid,', 'Ty', 'Dolla', '$ign', '&', '6LACK'],
#  ['Sugarland', 'Featuring', 'Taylor', 'Swift'],
#  ['Casper',
#   'Magico,',
#   'Nio',
#   'Garcia,',
#   'Darell,',
#   'Nicky',
#   'Jam,',
#   'Ozuna',
#   '&',
#   'Bad',
#   'Bunny'],
#  ['Pitbull',
#   'x',
#   'El',
#   'Chombo',
#   'x',
#   'Karol',
#   'G',
#   'Featuring',
#   'Cutty',
#   'Ranks'],
#  ['David', 'Lee', 'Murphy', '&', 'Kenny', 'Chesney'],
#  ['Rae', 'Sremmurd', '&', 'Travis', 'Scott'],
#  ['Post', 'Malone', 'Featuring', 'Swae', 'Lee'],
#  ['Post', 'Malone', 'Featuring', 'Nicki', 'Minaj'],
#  ['Post', 'Malone', 'Featuring', 'G-Eazy', '&', 'YG'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['Kanye', 'West', 'Featuring', 'T.I.'],
#  ['Travis', 'Scott', 'Featuring', 'Lil', 'Uzi', 'Vert', '&', 'Kanye', 'West'],
#  ['Shawn', 'Mendes', 'Featuring', 'Khalid'],
#  ['Charlie', 'Puth', 'Featuring', 'Kehlani'],
#  ['Bhad', 'Bhabie', 'Featuring', 'Lil', 'Yachty'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['Playboi', 'Carti', 'Featuring', 'Lil', 'Uzi', 'Vert'],
#  ['Lil', 'Baby', '&', 'Drake'],
#  ['Reik', 'Featuring', 'Ozuna', '&', 'Wisin'],
#  ['Lil', 'Baby', 'Featuring', 'Gunna', '&', 'Lil', 'Uzi', 'Vert'],
#  ['Pharrell', 'Williams', 'x', 'Camila', 'Cabello'],
#  ['Diplo,',
#   'French',
#   'Montana',
#   '&',
#   'Lil',
#   'Pump',
#   'Featuring',
#   'Zhavia',
#   'Ward'],
#  ['NAV', 'Featuring', 'Travis', 'Scott'],
#  ['A$AP', 'Rocky', 'Featuring', 'Skepta'],
#  ['6ix9ine', 'Featuring', 'DJ', 'SPINKING'],
#  ['YG', 'Featuring', '2', 'Chainz,', 'Big', 'Sean', '&', 'Nicki', 'Minaj'],
#  ['Pusha', 'T', 'Featuring', 'Kanye', 'West'],
#  ['Jennifer', 'Lopez', 'Featuring', 'DJ', 'Khaled', '&', 'Cardi', 'B'],
#  ['Tyga', 'Featuring', 'Offset'],
#  ['Billie', 'Eilish', '&', 'Khalid'],
#  ['Maroon', '5', 'Featuring', 'Cardi', 'B'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['Kanye', 'West', 'Featuring', 'PARTYNEXTDOOR'],
#  ['Kanye', 'West', 'Featuring', 'PARTYNEXTDOOR'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Gorillaz', 'Featuring', 'George', 'Benson'],
#  ['5', 'Seconds', 'Of', 'Summer'],
#  ['Becky', 'G', '+', 'Natti', 'Natasha'],
#  ['KIDS', 'SEE', 'GHOSTS'],
#  ['KIDS', 'SEE', 'GHOSTS', 'Featuring', 'Louis', 'Prima'],
#  ['KIDS', 'SEE', 'GHOSTS'],
#  ['KIDS', 'SEE', 'GHOSTS'],
#  ['KIDS', 'SEE', 'GHOSTS'],
#  ['KIDS', 'SEE', 'GHOSTS'],
#  ['KIDS', 'SEE', 'GHOSTS'],
#  ['Nicki', 'Minaj', 'Featuring', 'Lil', 'Wayne'],
#  ['Lil', 'Skies', 'Featuring', 'Yung', 'Pinch'],
#  ['Nicki', 'Minaj', 'Featuring', 'Ariana', 'Grande'],
#  ['2', 'Chainz,', 'Drake', '&', 'Quavo'],
#  ['Kygo', '&', 'Imagine', 'Dragons'],
#  ['Martin', 'Garrix', 'Featuring', 'Khalid'],
#  ['Jason', 'Aldean', 'Featuring', 'Miranda', 'Lambert'],
#  ['Nas', 'Featuring', 'Kanye', 'West'],
#  ['Keith', 'Urban', 'Featuring', 'Julia', 'Michaels'],
#  ['Ariana', 'Grande', 'Featuring', 'Nicki', 'Minaj'],
#  ['Clean', 'Bandit', 'Featuring', 'Demi', 'Lovato'],
#  ['Drake', 'Featuring', 'Michael', 'Jackson'],
#  ['Drake', 'Featuring', 'JAY-Z'],
#  ['Drake', 'Featuring', 'Static', 'Major', '&', 'Ty', 'Dolla', '$ign'],
#  ['twenty', 'one', 'pilots'],
#  ['Meek', 'Mill', 'Featuring', 'Swizz', 'Beatz'],
#  ['Meek', 'Mill', 'Featuring', 'Jeremih', '&', 'PnB', 'Rock'],
#  ['Tiesto', '&', 'Dzeko', 'Featuring', 'Preme', '&', 'Post', 'Malone'],
#  ['Iggy', 'Azalea', 'Feauring', 'Tyga'],
#  ['benny', 'blanco,', 'Halsey', '&', 'Khalid'],
#  ['Juice', 'WRLD', 'Featuring', 'Lil', 'Uzi', 'Vert'],
#  ['Wiz', 'Khalifa', 'Featuring', 'Swae', 'Lee'],
#  ['Wiz', 'Khalifa', 'Featuring', 'Lil', 'Skies'],
#  ['twenty', 'one', 'pilots'],
#  ['TK', 'Kravitz', 'Featuring', 'Jacqueez'],
#  ['G-Eazy', 'Featuring', 'Yo', 'Gotti', '&', 'YBN', 'Nahmir'],
#  ['Kygo', 'Featuring', 'Miguel'],
#  ['6ix9ine', 'Featuring', 'Nicki', 'Minaj', '&', 'Murda', 'Beatz'],
#  ['Chance', 'The', 'Rapper'],
#  ['Daniel', 'Caesar', 'Featuring', 'H.E.R.'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Justin',
#   'Bieber,',
#   'Chance',
#   'The',
#   'Rapper',
#   '&',
#   'Quavo'],
#  ['Logic', 'Featuring', 'Ryan', 'Tedder'],
#  ['The', 'Chainsmokers', 'Featuring', 'Emily', 'Warren'],
#  ['YG', 'Featuring', 'A$AP', 'Rocky'],
#  ['Bazzi', 'Featuring', 'Camila', 'Cabello'],
#  ['H.E.R.', 'Featuring', 'Bryson', 'Tiller'],
#  ['Nicki', 'Minaj', 'Featuring', 'Eminem', '&', 'Labrinth'],
#  ['Nicki', 'Minaj', 'Featuring', 'The', 'Weeknd'],
#  ['Marshmello', '&', 'Bastille'],
#  ['Calvin', 'Harris', '&', 'Sam', 'Smith'],
#  ['Young', 'Thug', 'Featuring', 'Gunna', '&', 'Lil', 'Baby'],
#  ['Janet', '&', 'Daddy', 'Yankee'],
#  ['BTS', 'Featuring', 'Nicki', 'Minaj'],
#  ['YoungBoy',
#   'Never',
#   'Broke',
#   'Again',
#   'Featuring',
#   'Kevin',
#   'Gates',
#   '&',
#   'Quando',
#   'Rondo'],
#  ["Lil'", 'Duval', 'Featuring', 'Snoop', 'Dogg', '&', 'Ball', 'Greezy'],
#  ['Zedd', '&', 'Elley', 'Duhe'],
#  ['Eminem', 'Featuring', 'Joyner', 'Lucas'],
#  ['Eminem', 'Featuring', 'Royce', 'Da', "5'9"],
#  ['6ix9ine', 'Featuring', 'Anuel', 'AA'],
#  ['Eminem', '&', 'Jessie', 'Reyez'],
#  ['Eminem', 'Featuring', 'Jessie', 'Reyez'],
#  ['Labrinth,', 'Sia', '&', 'Diplo', 'Present...', 'LSD'],
#  ['Kanye', 'West', '&', 'Lil', 'Pump'],
#  ['Machine', 'Gun', 'Kelly'],
#  ['Ozuna', 'x', 'Manuel', 'Turizo'],
#  ['Dan', '+', 'Shay'],
#  ['Silk', 'City', 'x', 'Dua', 'Lipa'],
#  ['Lil', 'Baby', '&', 'Gunna'],
#  ['Gucci', 'Mane', 'X', 'Bruno', 'Mars', 'X', 'Kodak', 'Black'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Lil', 'Peep', '&', 'XXXTENTACION'],
#  ['6LACK', 'Featuring', 'J.', 'Cole'],
#  ['French', 'Montana', 'Featuring', 'Drake'],
#  ['The', 'Chainsmokers', 'Featuring', 'Kelsea', 'Ballerini'],
#  ['Pardison', 'Fontaine', 'Featuring', 'Cardi', 'B'],
#  ['Lil', 'Wayne', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Lil', 'Wayne', 'Featuring', 'XXXTENTACION'],
#  ['Lil', 'Wayne', 'Featuring', 'Travis', 'Scott'],
#  ['Lil', 'Wayne', 'Featuring', 'Sosamann'],
#  ['Lil', 'Wayne', 'Featuring', 'Nicki', 'Minaj'],
#  ['DJ', 'Snake', 'Featuring', 'Selena', 'Gomez,', 'Ozuna', '&', 'Cardi', 'B'],
#  ['Lady', 'Gaga', '&', 'Bradley', 'Cooper'],
#  ['Lil', 'Wayne', 'Featuring', 'Reginae', 'Carter'],
#  ['Lil', 'Wayne', 'Featuring', 'Snoop', 'Dogg'],
#  ['Lil', 'Wayne', 'Featuring', 'Ashanti', '&', 'Mack', 'Maine'],
#  ['Lil', 'Wayne', 'Featuring', 'Nivea'],
#  ['Lil', 'Baby', '&', 'Gunna', 'Featuring', 'Drake'],
#  ['6ix9ine', 'Featuring', 'Bobby', 'Shmurda'],
#  ['Lil', 'Baby', '&', 'Gunna', 'Featuring', 'Lil', 'Durk', '&', 'NAV'],
#  ['Lil', 'Baby', '&', 'Gunna'],
#  ['Lil', 'Baby', '&', 'Gunna'],
#  ['twenty', 'one', 'pilots'],
#  ['Lil', 'Baby', '&', 'Gunna'],
#  ['Kodak', 'Black', 'Featuring', 'Travis', 'Scott', '&', 'Offset'],
#  ['Bad', 'Bunny', 'Featuring', 'Drake'],
#  ['Quavo', 'Featuring', 'Drake'],
#  ['Quavo', 'Featuring', '21', 'Savage'],
#  ['Quavo', 'Featuring', 'Travis', 'Scott'],
#  ['Quavo', 'Featuring', 'Lil', 'Baby'],
#  ['Post', 'Malone', '&', 'Swae', 'Lee'],
#  ['Future', '&', 'Juice', 'WRLD'],
#  ['Future', '&', 'Juice', 'WRLD', 'Featuring', 'Young', 'Scooter'],
#  ['Future', '&', 'Juice', 'WRLD'],
#  ['Khalid', '&', 'Kane', 'Brown'],
#  ['Khalid', 'Featuring', 'Empress', 'Of'],
#  ['Lil', 'Yachty', 'Featuring', 'Juice', 'WRLD'],
#  ['Dua', 'Lipa', '&', 'BLACKPINK'],
#  ['Lil', 'Yachty', 'Featuring', 'Playboi', 'Carti'],
#  ['Dierks', 'Bentley', 'Featuring', 'Brothers', 'Osborne'],
#  ['XXXTENTACION',
#   'x',
#   'Lil',
#   'Pump',
#   'Featuring',
#   'Maluma',
#   '&',
#   'Swae',
#   'Lee'],
#  ['Tory', 'Lanez', '&', 'Rich', 'The', 'Kid'],
#  ['Tyga', '&', 'Nicki', 'Minaj'],
#  ['Steve', 'Aoki', 'Featuring', 'BTS'],
#  ['Metro', 'Boomin', 'Featuring', '21', 'Savage'],
#  ['Metro', 'Boomin', 'Featuring', '21', 'Savage'],
#  ['Metro', 'Boomin', 'Featuring', 'Gunna'],
#  ['Metro', 'Boomin', 'Featuring', 'Travis', 'Scott'],
#  ['Metro', 'Boomin', 'Featuring', 'Swae', 'Lee', '&', 'Travis', 'Scott'],
#  ['Metro',
#   'Boomin',
#   'Featuring',
#   'Travis',
#   'Scott,',
#   'Kodak',
#   'Black',
#   '&',
#   '21',
#   'Savage'],
#  ['Anuel', 'AA', '&', 'Romeo', 'Santos'],
#  ['Metro', 'Boomin', 'Featuring', 'Travis', 'Scott', '&', 'Young', 'Thug'],
#  ['Trippie', 'Redd', 'Featuring', 'Juice', 'WRLD'],
#  ['Trippie', 'Redd', 'Featuring', 'Kodie', 'Shane'],
#  ['City', 'Girls', 'Featuring', 'Cardi', 'B'],
#  ['Ellie', 'Goulding', 'X', 'Diplo', 'Featuring', 'Swae', 'Lee'],
#  ['6ix9ine', 'Featuring', 'Nicki', 'Minaj', '&', 'Kanye', 'West'],
#  ['6ix9ine', 'Featuring', 'Tory', 'Lanez'],
#  ['6ix9ine', 'Featuring', 'Lil', 'Baby'],
#  ['6ix9ine', 'Featuring', 'A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ['Meek', 'Mill', 'Featuring', 'Drake'],
#  ['Meek', 'Mill', 'Featuring', 'Rick', 'Ross', '&', 'JAY-Z'],
#  ['Meek', 'Mill', 'Featuring', 'Cardi', 'B'],
#  ['Meek', 'Mill', 'Featuring', 'Fabolous', '&', 'Anuel', 'AA'],
#  ['Meek', 'Mill', 'Featuring', 'Ella', 'Mai'],
#  ['Nicki', 'Minaj', 'Featuring', 'Lil', 'Wayne'],
#  ['Lil', 'Baby', 'Featuring', 'Meek', 'Mill'],
#  ['Ski', 'Mask', 'The', 'Slump', 'God', 'Featuring', 'Juice', 'WRLD'],
#  ['Lil', 'Baby', 'Featuring', 'Gunna'],
#  ['Mark', 'Ronson', 'Featuring', 'Miley', 'Cyrus'],
#  ['Meek', 'Mill', 'Featuring', 'Kodak', 'Black'],
#  ['Meek',
#   'Mill',
#   'Featuring',
#   'Future,',
#   'Roddy',
#   'Ricch',
#   '&',
#   'Young',
#   'Thug'],
#  ['Meek', 'Mill', 'Featuring', '21', 'Savage'],
#  ['Ski', 'Mask', 'The', 'Slump', 'God'],
#  ['XXXTENTACION', 'Featuring', 'Kanye', 'West', '&', 'Travis', 'Barker'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ['Perry',
#   'Como',
#   'And',
#   'The',
#   'Fontane',
#   'Sisters',
#   'With',
#   'Mitchell',
#   'Ayres',
#   'And',
#   'His',
#   'Orchestra'],
#  ['John',
#   '&',
#   'Yoko/The',
#   'Plastic',
#   'Ono',
#   'Band',
#   'With',
#   'The',
#   'Harlem',
#   'Community',
#   'Choir'],
#  ['Kodak', 'Black', 'Featuring', 'Juice', 'WRLD'],
#  ['Kodak', 'Black', 'Featuring', 'Lil', 'Pump'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie', 'Featuring', '6ix9ine'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie', 'Featuring', 'Offset', '&', 'Tyga'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie', 'Featuring', 'Juice', 'WRLD'],
#  ['Loud', 'Luxury', 'Featuring', 'Brando'],
#  ['benny', 'blanco', '&', 'Juice', 'WRLD', 'Featuring', 'Brendon', 'Urie'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['Gesaffelstein', '&', 'The', 'Weeknd'],
#  ['Sam', 'Smith', '&', 'Normani'],
#  ['Kehlani', 'Featuring', 'Ty', 'Dolla', '$ign'],
#  ['Alec', 'Benjamin', '+', 'Alessia', 'Cara'],
#  ['Rich', 'The', 'Kid'],
#  ['Future', 'Featuring', 'Travis', 'Scott'],
#  ['Anuel', 'AA', '&', 'Karol', 'G'],
#  ['YNW', 'Melly', 'Featuring', 'Kanye', 'West'],
#  ['Mustard', '&', 'Migos'],
#  ['Hikaru', 'Utada', '&', 'Skrillex'],
#  ['Yo', 'Gotti', 'Featuring', 'Lil', 'Baby'],
#  ['Lauv', '&', 'Troye', 'Sivan'],
#  ['Daddy', 'Yankee', '&', 'Katy', 'Perry', 'Featuring', 'Snow'],
#  ['The', 'Chainsmokers', 'Featuring', '5', 'Seconds', 'Of', 'Summer'],
#  ['Cardi', 'B', '&', 'Bruno', 'Mars'],
#  ['Florida', 'Georgia', 'Line'],
#  ['Zedd', '&', 'Katy', 'Perry'],
#  ['Offset', 'Featuring', 'Travis', 'Scott', '&', '21', 'Savage'],
#  ['Offset', 'Featuring', 'Cardi', 'B'],
#  ['Offset', 'Featuring', 'J.', 'Cole'],
#  ['Lil', 'Pump', 'Featuring', 'Lil', 'Wayne'],
#  ['Gunna', 'Featuring', 'Young', 'Thug'],
#  ['Summer', 'Walker', 'X', 'Drake'],
#  ['Gunna', 'Featuring', 'Playboi', 'Carti'],
#  ['Ski', 'Mask', 'The', 'Slump', 'God'],
#  ['2', 'Chainz', 'Featuring', 'Travis', 'Scott'],
#  ['Lil', 'Nas', 'X', 'Featuring', 'Billy', 'Ray', 'Cyrus'],
#  ['benny', 'blanco,', 'Tainy,', 'Selena', 'Gomez', '&', 'J', 'Balvin'],
#  ['2', 'Chainz', 'Featuring', 'Ariana', 'Grande'],
#  ['2', 'Chainz', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Marshmello', 'Featuring', 'CHVRCHES'],
#  ['Pedro', 'Capo', 'X', 'Farruko'],
#  ['Lil', 'Peep', '&', 'iLoveMakonnen', 'Featuring', 'Fall', 'Out', 'Boy'],
#  ['NAV', 'Featuring', 'The', 'Weeknd'],
#  ['NAV', 'Featuring', 'Meek', 'Mill'],
#  ['Polo', 'G', 'Featuring', 'Lil', 'Tjay'],
#  ['Nipsey', 'Hussle', 'Featuring', 'Roddy', 'Ricch', '&', 'Hit-Boy'],
#  ['Nipsey', 'Hussle', 'Featuring', 'Belly', '&', 'DOM', 'KENNEDY'],
#  ['Ariana', 'Grande', '&', 'Victoria', 'Monet'],
#  ['Nipsey', 'Hussle', 'Featuring', 'YG'],
#  ['Nipsey', 'Hussle', 'Featuring', 'Kendrick', 'Lamar'],
#  ['Khalid', 'With', 'John', 'Mayer'],
#  ['Khalid', 'x', 'SAFE'],
#  ['Khalid', 'Featuring', 'A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ['Megan', 'Thee', 'Stallion'],
#  ['Nipsey', 'Hussle', 'Featuring', 'Stacy', 'Barthe'],
#  ['BTS', 'Featuring', 'Halsey'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Five',
#   'Finger',
#   'Death',
#   'Punch',
#   'Featuring',
#   'Kenny',
#   'Wayne',
#   'Shepherd,',
#   'Brantley',
#   'Gilbert',
#   '&',
#   'Brian',
#   'May'],
#  ['Avicii', 'Featuring', 'Aloe', 'Blacc'],
#  ['Lil', 'Uzi', 'Vert'],
#  ['Eli', 'Young', 'Band'],
#  ['BTS', 'Featuring', 'Lauv'],
#  ['Panic!', 'At', 'The', 'Disco'],
#  ['French', 'Montana', 'Featuring', 'Blueface', '&', 'Lil', 'Tjay'],
#  ['Taylor', 'Swift', 'Featuring', 'Brendon', 'Urie'],
#  ['ScHoolboy', 'Q', 'Featuring', '21', 'Savage'],
#  ['Ozuna',
#   'x',
#   'Daddy',
#   'Yankee',
#   'x',
#   'J',
#   'Balvin',
#   'x',
#   'Farruko',
#   'x',
#   'Anuel',
#   'AA'],
#  ['ScHoolboy', 'Q', '+', 'Travis', 'Scott'],
#  ['Marshmello,', 'Tyga', '&', 'Chris', 'Brown'],
#  ['SZA,', 'The', 'Weeknd', '&', 'Travis', 'Scott'],
#  ['P!nk', 'Featuring', 'Chris', 'Stapleton'],
#  ['Logic', 'Featuring', 'Eminem'],
#  ['YG,', 'Tyga', '&', 'Jon', 'Z'],
#  ['PnB', 'Rock', '&', 'XXXTENTACION'],
#  ['Dan', '+', 'Shay'],
#  ['Ed', 'Sheeran', '&', 'Justin', 'Bieber'],
#  ['Lunay,', 'Daddy', 'Yankee', '&', 'Bad', 'Bunny'],
#  ['Nicky', 'Jam', 'X', 'Ozuna'],
#  ['Tyler,', 'The', 'Creator'],
#  ['DJ', 'Khaled', 'Featuring', 'Cardi', 'B', '&', '21', 'Savage'],
#  ['DJ', 'Khaled', 'Featuring', 'Nipsey', 'Hussle', '&', 'John', 'Legend'],
#  ['DJ', 'Khaled', 'Featuring', 'SZA'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Meek',
#   'Mill,',
#   'J',
#   'Balvin,',
#   'Lil',
#   'Baby',
#   '&',
#   'Jeremih'],
#  ['Tyler,', 'The', 'Creator'],
#  ['DJ', 'Khaled', 'Featuring', 'Travis', 'Scott', '&', 'Post', 'Malone'],
#  ['DJ',
#   'Khaled',
#   'Featuring',
#   'Chris',
#   'Brown,',
#   'Lil',
#   'Wayne',
#   '&',
#   'Big',
#   'Sean'],
#  ['Tyler,', 'The', 'Creator'],
#  ['Tyler,', 'The', 'Creator'],
#  ['Tyler,', 'The', 'Creator'],
#  ['Tyler,', 'The', 'Creator'],
#  ['Tyler,', 'The', 'Creator'],
#  ['Tyler,', 'The', 'Creator'],
#  ['DJ', 'Khaled', 'Featuring', 'Meek', 'Mill', '&', 'Lil', 'Baby'],
#  ['Young', 'Thug,', 'J.', 'Cole', '&', 'Travis', 'Scott'],
#  ['Ed', 'Sheeran', 'Featuring', 'Chance', 'The', 'Rapper', '&', 'PnB', 'Rock'],
#  ['5', 'Seconds', 'Of', 'Summer'],
#  ['Joyner', 'Lucas', 'Featuring', 'Logic'],
#  ['Yella', 'Beezy,', 'Gucci', 'Mane', '&', 'Quavo'],
#  ['The', 'Chainsmokers', '&', 'Bebe', 'Rexha'],
#  ['John', 'Rich', 'Featuring', 'The', 'Five'],
#  ['Bryce', 'Vine', 'Featuring', 'YG'],
#  ['Chris', 'Brown', 'Featuring', 'Drake'],
#  ['Bad', 'Bunny', '&', 'Tainy'],
#  ['Sech,', 'Darell,', 'Nicky', 'Jam,', 'Ozuna', '&', 'Anuel', 'AA'],
#  ['Drake', 'Featuring', 'Rick', 'Ross'],
#  ['Dreamville',
#   'Featuring',
#   'JID,',
#   'Bas,',
#   'J.',
#   'Cole,',
#   'EARTHGANG',
#   '&',
#   'Young',
#   'Nudy'],
#  ['Marshmello', 'Featuring', 'A', 'Day', 'To', 'Remember'],
#  ['Shawn', 'Mendes', '&', 'Camila', 'Cabello'],
#  ['Lil', 'Nas', 'X'],
#  ['Lil', 'Nas', 'X', '&', 'Cardi', 'B', 'Or', 'Nas'],
#  ['Marshmello', '&', 'Kane', 'Brown'],
#  ['Lil', 'Baby', 'Featuring', 'Future'],
#  ['Megan', 'Thee', 'Stallion', 'Featuring', 'DaBaby'],
#  ['Martin', 'Garrix', 'Featuring', 'Macklemore', '&', 'Patrick', 'Stump'],
#  ['Ed', 'Sheeran', 'Featuring', 'Khalid'],
#  ['Kygo', 'X', 'Whitney', 'Houston'],
#  ['J', 'Balvin', '&', 'Bad', 'Bunny'],
#  ['Chris', 'Brown', 'Featuring', 'Justin', 'Bieber', '&', 'Ink'],
#  ['Y2K', '&', 'bbno$'],
#  ['Post', 'Malone', 'Featuring', 'Young', 'Thug'],
#  ['Dreamville', 'Featuring', 'J.', 'Cole,', 'Lute', '&', 'DaBaby'],
#  ['Ed', 'Sheeran', 'With', 'Chris', 'Stapleton', '&', 'Bruno', 'Mars'],
#  ['Dreamville',
#   'Featuring',
#   'Bas,',
#   'JID,',
#   'Guapdad',
#   '4000,',
#   'Reese',
#   'LAFLARE,',
#   'Jace,',
#   'Mez,',
#   'Smokepurpp,',
#   'Buddy',
#   '&',
#   'Ski',
#   'Mask',
#   'The',
#   'Slump',
#   'God'],
#  ['Jhay', 'Cortez,', 'J', 'Balvin', '&', 'Bad', 'Bunny'],
#  ['Ed', 'Sheeran', '&', 'Travis', 'Scott'],
#  ['Ed', 'Sheeran', 'Featuring', 'Camila', 'Cabello', '&', 'Cardi', 'B'],
#  ['Ed', 'Sheeran', 'Featuring', 'Eminem', '&', '50', 'Cent'],
#  ['Mustard',
#   'featuring',
#   'NAV,',
#   'Playboi',
#   'Carti',
#   '&',
#   'A',
#   'Boogie',
#   'Wit',
#   'da',
#   'Hoodie'],
#  ['Ed', 'Sheeran', 'Featuring', 'YEBBA'],
#  ['Lil', 'Baby', '&', 'DaBaby'],
#  ['Anuel',
#   'AA,',
#   'Daddy',
#   'Yankee,',
#   'Karol',
#   'G,',
#   'Ozuna',
#   '&',
#   'J',
#   'Balvin'],
#  ['Beyonce,',
#   'SAINt',
#   'JHN',
#   '&',
#   'Wizkid',
#   'Featuring',
#   'Blue',
#   'Ivy',
#   'Carter'],
#  ['Ellie', 'Goulding', '&', 'Juice', 'WRLD'],
#  ['Beyonce,',
#   'JAY-Z',
#   '&',
#   'Childish',
#   'Gambino',
#   'Featuring',
#   'Oumou',
#   'Sangare'],
#  ['Mustard', '&', 'Roddy', 'Ricch'],
#  ['Rick', 'Ross', 'Featuring', 'Drake'],
#  ['Chance', 'The', 'Rapper', 'Featuring', 'MadeinTYO', '&', 'DaBaby'],
#  ['The', 'Chainsmokers', '&', 'ILLENIUM', 'Featuring', 'Lennon', 'Stella'],
#  ['Blueface', '&', 'Rich', 'The', 'Kid'],
#  ['Chance', 'The', 'Rapper', 'Featuring', 'John', 'Legend'],
#  ['Chance', 'The', 'Rapper', 'Featuring', 'Death', 'Cab', 'For', 'Cutie'],
#  ['Ariana', 'Grande', '&', 'Social', 'House'],
#  ['Brantley', 'Gilbert', '+', 'Lindsay', 'Ell'],
#  ['Megan', 'Thee', 'Stallion,', 'Nicki', 'Minaj', '&', 'Ty', 'Dolla', '$ign'],
#  ['Trippie', 'Redd', 'Featuring', 'Lil', 'Baby', '&', 'Lil', 'Duke'],
#  ['Dove',
#   'Cameron,',
#   'Sofia',
#   'Carson,',
#   'Booboo',
#   'Stewart,',
#   'Cameron',
#   'Boyce,',
#   'Thomas',
#   'Doherty,',
#   'China',
#   'Anne',
#   'McClain',
#   '&',
#   'Dylan',
#   'Playfair'],
#  ['Wale', 'Featuring', 'Jeremih'],
#  ['DaBaby', 'Featuring', 'Offset'],
#  ['Young', 'Thug', 'Featuring', 'Gunna'],
#  ['Young', 'Thug', 'Featuring', 'Lil', 'Baby'],
#  ['Young', 'Thug', 'Featuring', 'Lil', 'Uzi', 'Vert'],
#  ['Young', 'Thug', 'Featuring', 'Gunna'],
#  ['Young', 'Thug', 'Featuring', 'Future'],
#  ['Swae', 'Lee', 'Featuring', 'Drake'],
#  ['Diplo', 'Presents', 'Thomas', 'Wesley', 'Featuring', 'Morgan', 'Wallen'],
#  ['Doja', 'Cat', '&', 'Tyga'],
#  ['Young', 'Thug', 'Featuring', 'Machine', 'Gun', 'Kelly'],
#  ['Taylor', 'Swift', 'Featuring', 'Dixie', 'Chicks'],
#  ['Lana', 'Del', 'Rey'],
#  ['Chris', 'Brown', 'Featuring', 'Gunna'],
#  ['Big', 'Sean', 'Featuring', 'A$AP', 'Ferg', '&', 'Hit-Boy'],
#  ['for', 'KING', '&', 'COUNTRY'],
#  ['J', 'Balvin', '&', 'Bad', 'Bunny'],
#  ['Post', 'Malone', 'Featuring', 'Ozzy', 'Osbourne', '&', 'Travis', 'Scott'],
#  ['Post', 'Malone', 'Featuring', 'DaBaby'],
#  ['Post', 'Malone', 'Featuring', 'Future', '&', 'Halsey'],
#  ['Post', 'Malone', 'Featuring', 'Meek', 'Mill', '&', 'Lil', 'Baby'],
#  ['Post', 'Malone', 'Featuring', 'SZA'],
#  ['YoungBoy', 'Never', 'Broke', 'Again'],
#  ['YNW', 'Melly', '&', '9lokknine'],
#  ['Ariana', 'Grande,', 'Miley', 'Cyrus', '&', 'Lana', 'Del', 'Rey'],
#  ['A', 'Boogie', 'Wit', 'da', 'Hoodie'],
#  ...]

# %% [markdown]
# # Searching for Spotify Song ID (Round 1)
# Some filtering to increase the success rate of each automatic search.
# The further we go back on the Billboard 100 list, the greater the number of songs are not available on the spotify platform.

# %%
unique_song_dict = {
    'song':[],
    'artist':[],
    'peak_rank':[],
    'total_weeks':[],
    'weeks':[],
    'spotify_id':[]
}

print('Working.', end='')
for ind, row in consolidated_tosearch.iterrows():
    musicians = row['artist']
    art = [i.lower().replace("'","") for i in musicians.split()]
    shit = ['featuring','feat.','(featuring','(duet','introducing','&','x','with','+',',']
    artist = ''
    for s in shit:
        if s in art:
            stop_pt = art.index(s)
            artist = ' '.join(art[:stop_pt])
            break
    if artist == '':
        artist = musicians 
        
    song = row['song']
    peak_rank = row['peak-rank']
    weeks_on_board = row['weeks_on_board']
    all_weeks = row['all_weeks']
    
    

    try:
        search = sp.search(q=f"{song} {artist}",type='track')

        if search['tracks']['items'][0]['id'] == '':
            z = float('NaN')
        else:
            z = search['tracks']['items'][0]['id']

        unique_song_dict['song'].append(song)
        unique_song_dict['artist'].append(row['artist'])
        unique_song_dict['peak_rank'].append(peak_rank)
        unique_song_dict['total_weeks'].append(weeks_on_board)
        unique_song_dict['weeks'].append(all_weeks)
        unique_song_dict['spotify_id'].append(z)
        print('.', end='')

    except:
        unique_song_dict['song'].append(song)
        unique_song_dict['artist'].append(row['artist'])
        unique_song_dict['peak_rank'].append(peak_rank)
        unique_song_dict['total_weeks'].append(weeks_on_board)
        unique_song_dict['weeks'].append(all_weeks)
        unique_song_dict['spotify_id'].append(float('NaN'))
        print(f'\nFailed to find Spot ID for {song} by {artist}')
# Out:
# Working.........................................................
# Failed to find Spot ID for Sun Daze by Florida Georgia Line
# ..............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Failed to find Spot ID for My Sh*t by A Boogie Wit da Hoodie
# ....................................................................
# Failed to find Spot ID for I Dont Wanna Live Forever (Fifty Shades Darker) by Zayn / Taylor Swift
# .............................................................................................................................................................................................................................................................................................................................................................
# Failed to find Spot ID for F**k Love by xxxtentacion
# .......................................................
# Failed to find Spot ID for Too Hotty by quavo, takeoff
# ......................
# Failed to find Spot ID for My Choppa Hate N****s by 21 savage
# ....................................................................................................................................................................................................................................
# Failed to find Spot ID for Dame Tu Cosita by pitbull x el chombo x karol g
# .....................................................................................
# Failed to find Spot ID for Bigger > You by 2 chainz, drake
# ....................................................
# Failed to find Spot ID for Kream by Iggy Azalea Feauring Tyga
# ....................................................
# Failed to find Spot ID for Ganja Burns by Nicki Minaj
# ..........................................................................
# Failed to find Spot ID for Dope N****z by lil wayne
# ....................................................................................
# Failed to find Spot ID for Close To Me by ellie goulding x diplo
# ..................................................................................................................................................................
# Failed to find Spot ID for Same Yung N***a by gunna
# .......................................................................................................................................................................................
# Failed to find Spot ID for Brown Skin Girl by beyonce, saint jhn & wizkid
# ..............................................................................................................................................................................................................................
# Failed to find Spot ID for Lord Above by fat joe & dre
# ...........

# %% [markdown]
# # Confirm API Search and Dict Length

# %%
for i in unique_song_dict.keys():
    print(len(unique_song_dict[i]))
# Out:
# 2500
# 2500
# 2500
# 2500
# 2500
# 2500

# %% [markdown]
# # Creating a New DataFrame including Spotify ID's found in Round1

# %%
spotify_billboard = pd.DataFrame(unique_song_dict)
spotify_billboard
# Out:
#                    song                                artist  peak_rank  \
# 0           Blank Space                          Taylor Swift          1
# 1     Take Me To Church                                Hozier          2
# 2          Uptown Funk!      Mark Ronson Featuring Bruno Mars          3
# 3     Thinking Out Loud                            Ed Sheeran          4
# 4        Lips Are Movin                        Meghan Trainor          4
# ...                 ...                                   ...        ...
# 2495     Nobody But You  Blake Shelton Duet With Gwen Stefani         79
# 2496        Famous Hoes                            NLE Choppa         83
# 2497             Cherry                          Harry Styles         84
# 2498             Golden                          Harry Styles         86
# 2499                She                          Harry Styles         99
#
#       total_weeks                                              weeks  \
# 0              29  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 1              23  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 2              51  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 3              48  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 4              21  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# ...           ...                                                ...
# 2495            1                                       [2019-12-28]
# 2496            1                                       [2019-12-28]
# 2497            1                                       [2019-12-28]
# 2498            1                                       [2019-12-28]
# 2499            1                                       [2019-12-28]
#
#                   spotify_id
# 0     1p80LdxRV74UKvL8gnD7ky
# 1     1CS7Sd1u5tWkstBhpssyjP
# 2     32OlwWuMpZ6b0aN2RZOeMS
# 3     34gCuhDGsG4bRPIf9bb02f
# 4     6gj08XDlv9Duc2fPOxUmVD
# ...                      ...
# 2495  5M8goiFYynmNxhueYW6grR
# 2496  35Xf2ABjPzUXKz19akd7Jj
# 2497  2IOFZdYYkFxEHVz1w34PoL
# 2498  45S5WTQEGOB1VHr1Q4FuPl
# 2499  6SQLk9HSNketfgs2AyIiMs
#
# [2500 rows x 6 columns]

# %% [markdown]
# # Getting Results for all songs that failed the Initial Search
# ### The cell loaded is for the 2015-2020 Billboard range, Newer music is almost all available on Spotify.
# The 1990-2000 range has ~330 songs that failed, 133 of which could not be found manually

# %%
spotify_billboard[spotify_billboard['spotify_id'].isna()]
# Out:
#                                                  song  \
# 56                                           Sun Daze
# 839                                           My Sh*t
# 908   I Dont Wanna Live Forever (Fifty Shades Darker)
# 1258                                        F**k Love
# 1314                                        Too Hotty
# 1337                            My Choppa Hate N****s
# 1566                                   Dame Tu Cosita
# 1652                                     Bigger > You
# 1705                                            Kream
# 1758                                      Ganja Burns
# 1833                                      Dope N****z
# 1918                                      Close To Me
# 2081                                  Same Yung N***a
# 2265                                  Brown Skin Girl
# 2488                                       Lord Above
#
#                                                  artist  peak_rank  \
# 56                                 Florida Georgia Line         57
# 839                              A Boogie Wit da Hoodie         98
# 908                                 Zayn / Taylor Swift          6
# 1258                XXXTENTACION Featuring Trippie Redd         41
# 1314                            Quavo, Takeoff & Offset         97
# 1337                           21 Savage & Metro Boomin         94
# 1566  Pitbull x El Chombo x Karol G Featuring Cutty ...         81
# 1652                            2 Chainz, Drake & Quavo         53
# 1705                          Iggy Azalea Feauring Tyga         96
# 1758                                        Nicki Minaj         60
# 1833                     Lil Wayne Featuring Snoop Dogg         39
# 1918          Ellie Goulding X Diplo Featuring Swae Lee         98
# 2081                      Gunna Featuring Playboi Carti         97
# 2265  Beyonce, SAINt JHN & Wizkid Featuring Blue Ivy...         76
# 2488     Fat Joe & Dre Featuring Eminem & Mary J. Blige         97
#
#       total_weeks                                              weeks  \
# 56             12  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 839            12  [2016-11-05, 2016-11-12, 2016-11-19, 2016-11-2...
# 908            23  [2016-12-31, 2017-01-07, 2017-01-14, 2017-01-2...
# 1258           20  [2017-09-16, 2017-09-23, 2017-09-30, 2017-10-0...
# 1314            4   [2017-10-28, 2017-11-04, 2017-11-11, 2017-11-18]
# 1337            2                           [2017-11-18, 2017-11-25]
# 1566            9  [2018-05-05, 2018-05-12, 2018-05-19, 2018-05-2...
# 1652            2                           [2018-06-30, 2018-07-07]
# 1705            1                                       [2018-07-21]
# 1758            1                                       [2018-08-25]
# 1833            1                                       [2018-10-13]
# 1918           25  [2018-12-01, 2018-12-08, 2018-12-15, 2018-12-2...
# 2081            1                                       [2019-03-09]
# 2265            1                                       [2019-08-03]
# 2488            1                                       [2019-12-21]
#
#      spotify_id
# 56          NaN
# 839         NaN
# 908         NaN
# 1258        NaN
# 1314        NaN
# 1337        NaN
# 1566        NaN
# 1652        NaN
# 1705        NaN
# 1758        NaN
# 1833        NaN
# 1918        NaN
# 2081        NaN
# 2265        NaN
# 2488        NaN

# %% [markdown]
# # Manually Searching the Tracks that Failed Round 1 using input boxes
# ## For anything that continues to fail, use 'pass' in your input prompt to skip it and it will be dropped from the DataFrame later

# %%
#try again
replace_these = []
for index, row in spotify_billboard[spotify_billboard['spotify_id'].isna()].iterrows():
    found = False
    while found == False:
        print(f"{row['song']} by {row['artist']}")
        to_search = input('What to search? - ')
        if to_search=='pass':
            found=True
        else:
            try:
                search = sp.search(q=f"{to_search}", type='track')
                print(f"{search['tracks']['items'][0]['id']} -- {row['song']} {row['artist']} -- Index: {index}\n")
                replace_these.append((search['tracks']['items'][0]['id'], index))
                found=True
            except:
                print('Could not Find, try again\n')
# Out:
# Sun Daze by Florida Georgia Line
# What to search? - sun daze florida georgia line
# 0El2Zyt68nYySFDG87hZgM -- Sun Daze Florida Georgia Line -- Index: 56
#
# My Sh*t by A Boogie Wit da Hoodie
# What to search? - my shit boogie wit da hoodie
# 5uQOauh47VFt3B2kV9kRXw -- My Sh*t A Boogie Wit da Hoodie -- Index: 839
#
# I Dont Wanna Live Forever (Fifty Shades Darker) by Zayn / Taylor Swift
# What to search? - i dont wanna live forever zayn taylor swift
# 55n9yjI6qqXh5F2mYvUc2y -- I Dont Wanna Live Forever (Fifty Shades Darker) Zayn / Taylor Swift -- Index: 908
#
# F**k Love by XXXTENTACION Featuring Trippie Redd
# What to search? - fuck love xxxtentacion
# 7AQim7LbvFVZJE3O8TYgf2 -- F**k Love XXXTENTACION Featuring Trippie Redd -- Index: 1258
#
# Too Hotty by Quavo, Takeoff & Offset
# What to search? - too hotty migos
# 3hWUIMNBwLNug1O8o2PPRW -- Too Hotty Quavo, Takeoff & Offset -- Index: 1314
#
# My Choppa Hate N****s by 21 Savage & Metro Boomin
# What to search? - my choppa hate niggas 21 savage
# 2D2w9943rsnJOGCrI4aMQp -- My Choppa Hate N****s 21 Savage & Metro Boomin -- Index: 1337
#
# Dame Tu Cosita by Pitbull x El Chombo x Karol G Featuring Cutty Ranks
# What to search? - dame tu cosita pitbull
# 2T7UAAVTIIuMZPOQLXTq1l -- Dame Tu Cosita Pitbull x El Chombo x Karol G Featuring Cutty Ranks -- Index: 1566
#
# Bigger > You by 2 Chainz, Drake & Quavo
# What to search? - bigger than you 2chainz
# 5S1IUPueD0xE0vj4zU3nSf -- Bigger > You 2 Chainz, Drake & Quavo -- Index: 1652
#
# Kream by Iggy Azalea Feauring Tyga
# What to search? - kream iggy azalea
# 5mu1uv8RmzDkF8foePK5qa -- Kream Iggy Azalea Feauring Tyga -- Index: 1705
#
# Ganja Burns by Nicki Minaj
# What to search? - ganja burns nicki
# 3LHYmz86DxGInsRp3wiiW5 -- Ganja Burns Nicki Minaj -- Index: 1758
#
# Dope N****z by Lil Wayne Featuring Snoop Dogg
# What to search? - dope niggaz lil wayne
# 2AwyHlbA6f641SEkizD5JG -- Dope N****z Lil Wayne Featuring Snoop Dogg -- Index: 1833
#
# Close To Me by Ellie Goulding X Diplo Featuring Swae Lee
# What to search? - close to me ellie goulding
# 5JEx7HbmvHQQswJCsoo9rA -- Close To Me Ellie Goulding X Diplo Featuring Swae Lee -- Index: 1918
#
# Same Yung N***a by Gunna Featuring Playboi Carti
# What to search? - same yung nigga gunna
# 1q9jq5X5vwmewjOa2mHtQ1 -- Same Yung N***a Gunna Featuring Playboi Carti -- Index: 2081
#
# Brown Skin Girl by Beyonce, SAINt JHN & Wizkid Featuring Blue Ivy Carter
# What to search? - brown skin girl beyonce
# 0B3FovCVaGKS5w1FTidEUP -- Brown Skin Girl Beyonce, SAINt JHN & Wizkid Featuring Blue Ivy Carter -- Index: 2265
#
# Lord Above by Fat Joe & Dre Featuring Eminem & Mary J. Blige
# What to search? - lord above fat joe
# 7q0VdsXafFQIYfk3eZpwTq -- Lord Above Fat Joe & Dre Featuring Eminem & Mary J. Blige -- Index: 2488

# %% [markdown]
# # Replacing NaN Values with the Searches above, Removing any stragglers.
# #### Use the append below for any that are way outside of searching

# %%
replace_these
# Out:
# [('0El2Zyt68nYySFDG87hZgM', 56),
#  ('5uQOauh47VFt3B2kV9kRXw', 839),
#  ('55n9yjI6qqXh5F2mYvUc2y', 908),
#  ('7AQim7LbvFVZJE3O8TYgf2', 1258),
#  ('3hWUIMNBwLNug1O8o2PPRW', 1314),
#  ('2D2w9943rsnJOGCrI4aMQp', 1337),
#  ('2T7UAAVTIIuMZPOQLXTq1l', 1566),
#  ('5S1IUPueD0xE0vj4zU3nSf', 1652),
#  ('5mu1uv8RmzDkF8foePK5qa', 1705),
#  ('3LHYmz86DxGInsRp3wiiW5', 1758),
#  ('2AwyHlbA6f641SEkizD5JG', 1833),
#  ('5JEx7HbmvHQQswJCsoo9rA', 1918),
#  ('1q9jq5X5vwmewjOa2mHtQ1', 2081),
#  ('0B3FovCVaGKS5w1FTidEUP', 2265),
#  ('7q0VdsXafFQIYfk3eZpwTq', 2488)]

# %%
# replacing values for the searches above
for i in replace_these:
    spotify_billboard.iloc[i[1],5] = i[0]

# %% [markdown]
# # Dropping and Confirming no NaN Values
# 2015-2020 all songs are on spotify

# %%
#this cell should output an empty dataframe
spotify_billboard[spotify_billboard['spotify_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [song, artist, peak_rank, total_weeks, weeks, spotify_id]
# Index: []

# %%
spotify_billboard
# Out:
#                    song                                artist  peak_rank  \
# 0           Blank Space                          Taylor Swift          1
# 1     Take Me To Church                                Hozier          2
# 2          Uptown Funk!      Mark Ronson Featuring Bruno Mars          3
# 3     Thinking Out Loud                            Ed Sheeran          4
# 4        Lips Are Movin                        Meghan Trainor          4
# ...                 ...                                   ...        ...
# 2495     Nobody But You  Blake Shelton Duet With Gwen Stefani         79
# 2496        Famous Hoes                            NLE Choppa         83
# 2497             Cherry                          Harry Styles         84
# 2498             Golden                          Harry Styles         86
# 2499                She                          Harry Styles         99
#
#       total_weeks                                              weeks  \
# 0              29  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 1              23  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 2              51  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 3              48  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# 4              21  [2015-01-03, 2015-01-10, 2015-01-17, 2015-01-2...
# ...           ...                                                ...
# 2495            1                                       [2019-12-28]
# 2496            1                                       [2019-12-28]
# 2497            1                                       [2019-12-28]
# 2498            1                                       [2019-12-28]
# 2499            1                                       [2019-12-28]
#
#                   spotify_id
# 0     1p80LdxRV74UKvL8gnD7ky
# 1     1CS7Sd1u5tWkstBhpssyjP
# 2     32OlwWuMpZ6b0aN2RZOeMS
# 3     34gCuhDGsG4bRPIf9bb02f
# 4     6gj08XDlv9Duc2fPOxUmVD
# ...                      ...
# 2495  5M8goiFYynmNxhueYW6grR
# 2496  35Xf2ABjPzUXKz19akd7Jj
# 2497  2IOFZdYYkFxEHVz1w34PoL
# 2498  45S5WTQEGOB1VHr1Q4FuPl
# 2499  6SQLk9HSNketfgs2AyIiMs
#
# [2500 rows x 6 columns]

# %% [markdown]
# # Saving DF to CSV - Just Song/Billboard Info and Spotify ID
# Make a folder called "Spotify_IDs" if you want to save at this step in the process

# %%
spotify_billboard.to_csv(f'Spotify_IDs/SPOTIFY_ID_BILLBOARD_{filter_range}.csv', index=False)

# %% [markdown]
# # Searching for Audio Features by Spotify ID for all Rows in our latest DF

# %%
features = {
    'danceability':[],
    'energy':[],
    'loudness':[],
    'speechiness':[],
    'acousticness':[],
    'instrumentalness':[],
    'liveness':[],
    'valence':[],
    'tempo':[]
}

for h,i in enumerate(spotify_billboard['spotify_id']):
    tot = len(spotify_billboard['spotify_id'])
    try:
        
        search = sp.audio_features(i)
   
        features['danceability'].append(search[0]['danceability'])
        features['energy'].append(search[0]['energy'])
        features['loudness'].append(search[0]['loudness'])
        features['speechiness'].append(search[0]['speechiness'])
        features['acousticness'].append(search[0]['acousticness'])
        features['instrumentalness'].append(search[0]['instrumentalness'])
        features['liveness'].append(search[0]['liveness'])
        features['valence'].append(search[0]['valence'])
        features['tempo'].append(search[0]['tempo'])
    except:
        for j in features.keys():
            features[j].append(float('NaN'))

    print('.', end='')
# Out:
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Confirm length of lists in our output dictionary above

# %%
for i in features.keys():
    print(len(features[i]))
# Out:
# 2500
# 2500
# 2500
# 2500
# 2500
# 2500
# 2500
# 2500
# 2500

# %%
billboard_spotify_features = spotify_billboard.copy()

# %%
billboard_spotify_features['danceability'] = features['danceability']
billboard_spotify_features['energy'] = features['energy']
billboard_spotify_features['loudness'] = features['loudness']
billboard_spotify_features['speechiness'] = features['speechiness']
billboard_spotify_features['acousticness'] = features['acousticness']
billboard_spotify_features['instrumentalness'] = features['instrumentalness']
billboard_spotify_features['liveness'] = features['liveness']
billboard_spotify_features['valence'] = features['valence']
billboard_spotify_features['tempo'] = features['tempo']

# %%
billboard_spotify_features.tail()
# Out:
#                 song                                artist  peak_rank  \
# 2495  Nobody But You  Blake Shelton Duet With Gwen Stefani         79
# 2496     Famous Hoes                            NLE Choppa         83
# 2497          Cherry                          Harry Styles         84
# 2498          Golden                          Harry Styles         86
# 2499             She                          Harry Styles         99
#
#       total_weeks         weeks              spotify_id  danceability  energy  \
# 2495            1  [2019-12-28]  5M8goiFYynmNxhueYW6grR         0.463   0.653
# 2496            1  [2019-12-28]  35Xf2ABjPzUXKz19akd7Jj         0.732   0.627
# 2497            1  [2019-12-28]  2IOFZdYYkFxEHVz1w34PoL         0.530   0.512
# 2498            1  [2019-12-28]  45S5WTQEGOB1VHr1Q4FuPl         0.448   0.838
# 2499            1  [2019-12-28]  6SQLk9HSNketfgs2AyIiMs         0.535   0.521
#
#       loudness  speechiness  acousticness  instrumentalness  liveness  \
# 2495    -5.515       0.0273      0.111000          0.000136     0.172
# 2496    -5.693       0.1610      0.346000          0.000000     0.261
# 2497    -9.261       0.0259      0.615000          0.004530     0.129
# 2498    -5.257       0.0557      0.210000          0.000131     0.131
# 2499    -5.942       0.0272      0.000532          0.371000     0.190
#
#       valence    tempo
# 2495    0.233  143.912
# 2496    0.332   81.481
# 2497    0.411   95.946
# 2498    0.254  139.863
# 2499    0.457  140.026

# %%
billboard_spotify_features[billboard_spotify_features['danceability']=='NaN']
# Out:
# Empty DataFrame
# Columns: [song, artist, peak_rank, total_weeks, weeks, spotify_id, danceability, energy, loudness, speechiness, acousticness, instrumentalness, liveness, valence, tempo]
# Index: []

# %% [markdown]
# # Save DF with Audio Features - Condensed (optional)
# Saves to a folder named 'Features'

# %%
billboard_spotify_features.to_csv(f'Features/Features_Condensed_{filter_range}.csv', index=False)

# %% [markdown]
# # expanding the unique track/artist dataframe above by the list of weeks

# %%
billboard_spotify_expanded = billboard_spotify_features.explode('weeks').reset_index(drop=True)

# %%
billboard_spotify_expanded
# Out:
#                  song                                artist  peak_rank  \
# 0         Blank Space                          Taylor Swift          1
# 1         Blank Space                          Taylor Swift          1
# 2         Blank Space                          Taylor Swift          1
# 3         Blank Space                          Taylor Swift          1
# 4         Blank Space                          Taylor Swift          1
# ...               ...                                   ...        ...
# 26095  Nobody But You  Blake Shelton Duet With Gwen Stefani         79
# 26096     Famous Hoes                            NLE Choppa         83
# 26097          Cherry                          Harry Styles         84
# 26098          Golden                          Harry Styles         86
# 26099             She                          Harry Styles         99
#
#        total_weeks       weeks              spotify_id  danceability  energy  \
# 0               29  2015-01-03  1p80LdxRV74UKvL8gnD7ky         0.752   0.678
# 1               29  2015-01-10  1p80LdxRV74UKvL8gnD7ky         0.752   0.678
# 2               29  2015-01-17  1p80LdxRV74UKvL8gnD7ky         0.752   0.678
# 3               29  2015-01-24  1p80LdxRV74UKvL8gnD7ky         0.752   0.678
# 4               29  2015-01-31  1p80LdxRV74UKvL8gnD7ky         0.752   0.678
# ...            ...         ...                     ...           ...     ...
# 26095            1  2019-12-28  5M8goiFYynmNxhueYW6grR         0.463   0.653
# 26096            1  2019-12-28  35Xf2ABjPzUXKz19akd7Jj         0.732   0.627
# 26097            1  2019-12-28  2IOFZdYYkFxEHVz1w34PoL         0.530   0.512
# 26098            1  2019-12-28  45S5WTQEGOB1VHr1Q4FuPl         0.448   0.838
# 26099            1  2019-12-28  6SQLk9HSNketfgs2AyIiMs         0.535   0.521
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0        -5.421       0.0646      0.085000          0.000002     0.130
# 1        -5.421       0.0646      0.085000          0.000002     0.130
# 2        -5.421       0.0646      0.085000          0.000002     0.130
# 3        -5.421       0.0646      0.085000          0.000002     0.130
# 4        -5.421       0.0646      0.085000          0.000002     0.130
# ...         ...          ...           ...               ...       ...
# 26095    -5.515       0.0273      0.111000          0.000136     0.172
# 26096    -5.693       0.1610      0.346000          0.000000     0.261
# 26097    -9.261       0.0259      0.615000          0.004530     0.129
# 26098    -5.257       0.0557      0.210000          0.000131     0.131
# 26099    -5.942       0.0272      0.000532          0.371000     0.190
#
#        valence    tempo
# 0        0.583   96.009
# 1        0.583   96.009
# 2        0.583   96.009
# 3        0.583   96.009
# 4        0.583   96.009
# ...        ...      ...
# 26095    0.233  143.912
# 26096    0.332   81.481
# 26097    0.411   95.946
# 26098    0.254  139.863
# 26099    0.457  140.026
#
# [26100 rows x 15 columns]

# %%
all_weeks = sorted(list(set(billboard_spotify_expanded['weeks'])))
all_weeks
# Out:
# ['2015-01-03',
#  '2015-01-10',
#  '2015-01-17',
#  '2015-01-24',
#  '2015-01-31',
#  '2015-02-07',
#  '2015-02-14',
#  '2015-02-21',
#  '2015-02-28',
#  '2015-03-07',
#  '2015-03-14',
#  '2015-03-21',
#  '2015-03-28',
#  '2015-04-04',
#  '2015-04-11',
#  '2015-04-18',
#  '2015-04-25',
#  '2015-05-02',
#  '2015-05-09',
#  '2015-05-16',
#  '2015-05-23',
#  '2015-05-30',
#  '2015-06-06',
#  '2015-06-13',
#  '2015-06-20',
#  '2015-06-27',
#  '2015-07-04',
#  '2015-07-11',
#  '2015-07-18',
#  '2015-07-25',
#  '2015-08-01',
#  '2015-08-08',
#  '2015-08-15',
#  '2015-08-22',
#  '2015-08-29',
#  '2015-09-05',
#  '2015-09-12',
#  '2015-09-19',
#  '2015-09-26',
#  '2015-10-03',
#  '2015-10-10',
#  '2015-10-17',
#  '2015-10-24',
#  '2015-10-31',
#  '2015-11-07',
#  '2015-11-14',
#  '2015-11-21',
#  '2015-11-28',
#  '2015-12-05',
#  '2015-12-12',
#  '2015-12-19',
#  '2015-12-26',
#  '2016-01-02',
#  '2016-01-09',
#  '2016-01-16',
#  '2016-01-23',
#  '2016-01-30',
#  '2016-02-06',
#  '2016-02-13',
#  '2016-02-20',
#  '2016-02-27',
#  '2016-03-05',
#  '2016-03-12',
#  '2016-03-19',
#  '2016-03-26',
#  '2016-04-02',
#  '2016-04-09',
#  '2016-04-16',
#  '2016-04-23',
#  '2016-04-30',
#  '2016-05-07',
#  '2016-05-14',
#  '2016-05-21',
#  '2016-05-28',
#  '2016-06-04',
#  '2016-06-11',
#  '2016-06-18',
#  '2016-06-25',
#  '2016-07-02',
#  '2016-07-09',
#  '2016-07-16',
#  '2016-07-23',
#  '2016-07-30',
#  '2016-08-06',
#  '2016-08-13',
#  '2016-08-20',
#  '2016-08-27',
#  '2016-09-03',
#  '2016-09-10',
#  '2016-09-17',
#  '2016-09-24',
#  '2016-10-01',
#  '2016-10-08',
#  '2016-10-15',
#  '2016-10-22',
#  '2016-10-29',
#  '2016-11-05',
#  '2016-11-12',
#  '2016-11-19',
#  '2016-11-26',
#  '2016-12-03',
#  '2016-12-10',
#  '2016-12-17',
#  '2016-12-24',
#  '2016-12-31',
#  '2017-01-07',
#  '2017-01-14',
#  '2017-01-21',
#  '2017-01-28',
#  '2017-02-04',
#  '2017-02-11',
#  '2017-02-18',
#  '2017-02-25',
#  '2017-03-04',
#  '2017-03-11',
#  '2017-03-18',
#  '2017-03-25',
#  '2017-04-01',
#  '2017-04-08',
#  '2017-04-15',
#  '2017-04-22',
#  '2017-04-29',
#  '2017-05-06',
#  '2017-05-13',
#  '2017-05-20',
#  '2017-05-27',
#  '2017-06-03',
#  '2017-06-10',
#  '2017-06-17',
#  '2017-06-24',
#  '2017-07-01',
#  '2017-07-08',
#  '2017-07-15',
#  '2017-07-22',
#  '2017-07-29',
#  '2017-08-05',
#  '2017-08-12',
#  '2017-08-19',
#  '2017-08-26',
#  '2017-09-02',
#  '2017-09-09',
#  '2017-09-16',
#  '2017-09-23',
#  '2017-09-30',
#  '2017-10-07',
#  '2017-10-14',
#  '2017-10-21',
#  '2017-10-28',
#  '2017-11-04',
#  '2017-11-11',
#  '2017-11-18',
#  '2017-11-25',
#  '2017-12-02',
#  '2017-12-09',
#  '2017-12-16',
#  '2017-12-23',
#  '2017-12-30',
#  '2018-01-06',
#  '2018-01-13',
#  '2018-01-20',
#  '2018-01-27',
#  '2018-02-03',
#  '2018-02-10',
#  '2018-02-17',
#  '2018-02-24',
#  '2018-03-03',
#  '2018-03-10',
#  '2018-03-17',
#  '2018-03-24',
#  '2018-03-31',
#  '2018-04-07',
#  '2018-04-14',
#  '2018-04-21',
#  '2018-04-28',
#  '2018-05-05',
#  '2018-05-12',
#  '2018-05-19',
#  '2018-05-26',
#  '2018-06-02',
#  '2018-06-09',
#  '2018-06-16',
#  '2018-06-23',
#  '2018-06-30',
#  '2018-07-07',
#  '2018-07-14',
#  '2018-07-21',
#  '2018-07-28',
#  '2018-08-04',
#  '2018-08-11',
#  '2018-08-18',
#  '2018-08-25',
#  '2018-09-01',
#  '2018-09-08',
#  '2018-09-15',
#  '2018-09-22',
#  '2018-09-29',
#  '2018-10-06',
#  '2018-10-13',
#  '2018-10-20',
#  '2018-10-27',
#  '2018-11-03',
#  '2018-11-10',
#  '2018-11-17',
#  '2018-11-24',
#  '2018-12-01',
#  '2018-12-08',
#  '2018-12-15',
#  '2018-12-22',
#  '2018-12-29',
#  '2019-01-05',
#  '2019-01-12',
#  '2019-01-19',
#  '2019-01-26',
#  '2019-02-02',
#  '2019-02-09',
#  '2019-02-16',
#  '2019-02-23',
#  '2019-03-02',
#  '2019-03-09',
#  '2019-03-16',
#  '2019-03-23',
#  '2019-03-30',
#  '2019-04-06',
#  '2019-04-13',
#  '2019-04-20',
#  '2019-04-27',
#  '2019-05-04',
#  '2019-05-11',
#  '2019-05-18',
#  '2019-05-25',
#  '2019-06-01',
#  '2019-06-08',
#  '2019-06-15',
#  '2019-06-22',
#  '2019-06-29',
#  '2019-07-06',
#  '2019-07-13',
#  '2019-07-20',
#  '2019-07-27',
#  '2019-08-03',
#  '2019-08-10',
#  '2019-08-17',
#  '2019-08-24',
#  '2019-08-31',
#  '2019-09-07',
#  '2019-09-14',
#  '2019-09-21',
#  '2019-09-28',
#  '2019-10-05',
#  '2019-10-12',
#  '2019-10-19',
#  '2019-10-26',
#  '2019-11-02',
#  '2019-11-09',
#  '2019-11-16',
#  '2019-11-23',
#  '2019-11-30',
#  '2019-12-07',
#  '2019-12-14',
#  '2019-12-21',
#  '2019-12-28']

# %% [markdown]
# # Creating a DF of average audio feature by week

# %%
average_audio_features = billboard_spotify_expanded.groupby('weeks').mean()[['danceability','energy','loudness','speechiness',
                                                   'acousticness','instrumentalness','liveness','valence','tempo']]
average_audio_features = average_audio_features.rename(columns={'danceability':'danceability_avg',
                                                                        'energy':'energy_avg',
                                                                        'loudness':'loudness_avg',
                                                                        'speechiness':'speechiness_avg',
                                                                        'acousticness':'acousticness_avg',
                                                                        'instrumentalness':'instrumentalness_avg',
                                                                        'liveness':'liveness_avg',
                                                                        'valence':'valence_avg',
                                                                        'tempo':'tempo_avg'})

# %%
average_audio_features
# Out:
#             danceability_avg  energy_avg  loudness_avg  speechiness_avg  \
# weeks
# 2015-01-03           0.63033    0.678523      -6.01788         0.085307
# 2015-01-10           0.63922    0.689513      -5.88143         0.083772
# 2015-01-17           0.63595    0.682273      -5.91040         0.081830
# 2015-01-24           0.62964    0.688593      -5.84467         0.077276
# 2015-01-31           0.62859    0.686523      -5.82135         0.075536
# ...                      ...         ...           ...              ...
# 2019-11-30           0.68050    0.622630      -6.13101         0.134666
# 2019-12-07           0.66947    0.603250      -6.36134         0.124137
# 2019-12-14           0.66165    0.593800      -6.85570         0.118458
# 2019-12-21           0.65738    0.596610      -6.74606         0.105254
# 2019-12-28           0.66119    0.580150      -6.91382         0.099135
#
#             acousticness_avg  instrumentalness_avg  liveness_avg  valence_avg  \
# weeks
# 2015-01-03          0.173665              0.001144      0.191614     0.493561
# 2015-01-10          0.157524              0.001171      0.198832     0.500751
# 2015-01-17          0.176445              0.001168      0.188154     0.487091
# 2015-01-24          0.159706              0.001681      0.188570     0.496414
# 2015-01-31          0.166731              0.001177      0.190216     0.490854
# ...                      ...                   ...           ...          ...
# 2019-11-30          0.201180              0.009509      0.157982     0.505003
# 2019-12-07          0.244060              0.009414      0.161925     0.500593
# 2019-12-14          0.275300              0.009416      0.164756     0.523363
# 2019-12-21          0.262279              0.008002      0.186568     0.517043
# 2019-12-28          0.278865              0.011787      0.187745     0.502355
#
#             tempo_avg
# weeks
# 2015-01-03  122.80917
# 2015-01-10  121.03907
# 2015-01-17  121.89695
# 2015-01-24  123.59163
# 2015-01-31  122.65702
# ...               ...
# 2019-11-30  115.81626
# 2019-12-07  117.66386
# 2019-12-14  119.27327
# 2019-12-21  116.91367
# 2019-12-28  117.46844
#
# [261 rows x 9 columns]

# %% [markdown]
# # Save Final CSV to Plot
# Make a folder named Average_Features

# %%
average_audio_features.to_csv(f'Average_Features/avg_audio_features({filter_range})_4.27.csv', index=False)
